# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     2,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-08-01T00:00:00Z"
experiment_end_date = "2000-09-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle.forcing import sources

# %%
camels_forcing = sources.HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'0{HRU_id}_lump_cida_forcing_leap.txt',
                          alpha = alpha
                          )

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 30

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
# this initializes the models for all ensemble members. 
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[camels_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst)

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %%
observations = observations_path / f'0{HRU_id}_streamflow_qc.txt'

# %%
cubic_ft_to_cubic_m = 0.0283168466

# %%
new_header = ['GAGEID','Year','Month', 'Day', 'Streamflow(cubic feet per second)','QC_flag']
new_header_dict = dict(list(zip(range(len(new_header)),new_header)))

df_Q = pd.read_fwf(observations,delimiter=' ',encoding='utf-8',header=None)
df_Q = df_Q.rename(columns=new_header_dict)
df_Q['Streamflow(cubic feet per second)'] = df_Q['Streamflow(cubic feet per second)'].apply(lambda x: np.nan if x==-999.00 else x)
df_Q['Q (m3/s)'] = df_Q['Streamflow(cubic feet per second)'] * cubic_ft_to_cubic_m
df_Q['Q'] = df_Q['Q (m3/s)'] / ds.attrs['area basin(m^2)'] * 3600 * 24 * 1000 # m3/s -> m/s ->m/d -> mm/d
df_Q.index = df_Q.apply(lambda x: pd.Timestamp(f'{int(x.Year)}-{int(x.Month)}-{int(x.Day)}'),axis=1)
df_Q.index.name = "time"
df_Q.drop(columns=['Year','Month', 'Day','Streamflow(cubic feet per second)'],inplace=True)
df_Q = df_Q.dropna(axis=0)

ds_obs_dir = observations_path / f'0{HRU_id}_streamflow_qc.nc'
ds_obs = xr.Dataset(data_vars=df_Q[['Q']])
if not ds_obs_dir.exists():
    ds_obs.to_netcdf(ds_obs_dir)

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
def H(Z):
    if len(Z) == 13:
        return Z[-1] 
    else: 
        raise SyntaxWarning(f"Length of statevector should be 9 but is {len(Z)}")

# %%
ensemble.initialize_da_method(ensemble_method_name = "PF", 
                              hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.01,
                                                 },
                              
                              state_vector_variables = "all", # the next three are keyword arguments but are needed. 
                              observation_path = ds_obs_dir,
                              observed_variable_name = "Q",
                              measurement_operator = H, 
                           
                            )

# %% [markdown]
# ## Run

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.19652759626545624,0.2201035299306744,137.55375294002016,3.015524031152083,0.06866451731648429,1'
#                     '.1719822545917093,0.027236387696322147,0.0051187087227584525'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145702/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.745799512814102,0.7463261756263706,729.8180834590953,3.9029282205283344,0.020008150672645768,1.'
#                     '3509542075571206,0.08595127492799783,0.007935946545337351'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145703/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.734956407112304,0.33694557441547857,668.555555809346,0.5041688461803215,0.293101264039338,1.359'
#                     '4955185225928,0.08198842370152704,0.00017066908621995422'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145705/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.769269824025056,0.7582681606406656,630.4029816578221,1.1242008930048635,0.053634035422251404,1.'
#                     '9476118419238462,0.051345886958319445,0.00327613533843224'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145707/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.051877328626385,0.870020385818038,367.10647379634804,1.8052342762411029,0.06056020127177244,1.5'
#                     '221312203744084,0.04928328562041836,0.006722909985631904'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145709/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.5136864975079085,0.6578512648615258,402.0209140484059,2.2102919855701106,0.2092774395486786,1.5'
#                     '566692485117928,0.0675297880838701,0.00802654224171677'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145711/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.429866169296008,0.6577587725845833,200.9746052520139,1.6320053614123773,0.026318504232373162,1.'
#                     '5457023667371543,0.05945723082942259,0.003944541078487246'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145713/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.21407933538879,0.4967196537764418,557.2704746861682,3.0112741017387497,0.14914671389272738,1.02'
#                     '00065404316863,0.08747055434632987,0.0015739868399334174'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145715/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.593567469241353,0.9502001696961799,130.55678794591466,2.869837307840159,0.14786476497114454,1.4'
#                     '244624886647772,0.02681171266304229,0.0060499012625055155'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145716/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.441430580394706,0.3170731295358866,715.672215201082,0.7974778907565065,0.12118098585395681,1.97'
#                     '85577280593345,0.053688677114879374,0.00181442582726999'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145718/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.2141281889871056,0.2510039858898405,515.4691593668451,1.6004208807117013,0.1491023982476786,1.0'
#                     '963670493382989,0.09961486393851521,0.002611429409170607'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145720/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.383473773221364,0.691173618207854,63.64136531657873,1.8417240451245398,0.12746811714671577,1.46'
#                     '8854951711029,0.0860188897770055,0.0012948819650501662'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145722/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.2451020157917085,0.34398101869820985,208.9365972930736,1.733565285500839,0.28369583697966755,1.'
#                     '8024622024992505,0.024084677909708474,0.0015478947601884035'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145724/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.3426896997351827,0.5635238113513648,453.50231899148855,1.9980542645645425,0.12433899283908073,1'
#                     '.2591629721971582,0.046215072211370674,0.009143168386367648'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145726/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.0653273818008824,0.5791693934944968,352.22304257862163,1.2703697107008611,0.27260167153822357,1'
#                     '.595509274572543,0.03025044311202836,0.003396788775301352'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145728/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.75204846637258,0.40874342557257415,649.8194025212836,0.6599692481235273,0.21429231449495736,1.9'
#                     '919674690209623,0.09655787808701109,0.00015416805574631822'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145729/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.384451735572626,0.8321612107335761,300.8439682279849,3.904179471704021,0.1755567942737962,1.937'
#                     '6600583740486,0.03662550500095751,0.002040581758244302'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145731/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.4297361321348676,0.47330684363430325,74.39325111565482,0.5537614608958525,0.25461001254437227,1'
#                     '.1909870271006229,0.07443252709588352,0.005326078689185223'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145733/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.07071265523119,0.6260362334090599,573.4017189521757,1.032120910381075,0.27460075574840703,1.509'
#                     '6090565169877,0.08233009358768557,0.0023435476803435247'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145735/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.940641433707143,0.9218151619399522,722.0462776814098,1.0727970337523125,0.081996765379645,1.254'
#                     '5885154728298,0.04043340015914248,0.004280969815555141'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145737/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.49225179534194297,0.35134171504138667,429.1931924322703,3.0832068534447927,0.001029228892348527'
#                     '8,1.389430087791887,0.09783869343468249,0.004640758441660914'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145738/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.773003267017929,0.9179848517260478,568.3964486892709,3.2644605846345502,0.28218305368382485,1.8'
#                     '831745777129831,0.06156125097451215,0.007592344790606666'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145740/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.7532828069327504,0.4392752961857627,512.98153478154,3.416413119937378,0.03929795924341722,1.503'
#                     '8635847888084,0.09717642239365636,0.0091996550564099'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145742/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.979437961487265,0.9894038111212227,772.9470408980234,2.143920780853792,0.20031960378505767,1.15'
#                     '06459961765407,0.09583502264396054,0.00959931136686629'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145744/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.461153655133181,0.6921819990649758,581.3332211696609,1.0719016360184275,0.2584311030592769,1.17'
#                     '4319205838595,0.018855121017553447,0.004199041054529641'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145746/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.0026933421662027612,0.5504545086866577,567.5172408757745,1.8646501607319956,0.20863314566842953'
#                     ',1.017859464572341,0.0540976448925975,0.003264155268238437'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145748/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.515333255804285,0.828122762601275,708.932570218815,1.1264098346341227,0.14409179300523312,1.778'
#                     '7089483987564,0.05926311185747591,0.0013993374454081826'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145749/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.751062509087885,0.9024619655428698,686.5792235373953,3.8735210029476277,0.26445372339265577,1.6'
#                     '472451569098903,0.08776526256016802,0.0025579822235460075'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145751/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.334957966596359,0.2341911465378207,362.1834092557621,2.115329225210246,0.16036318860068235,1.45'
#                     '5380808648508,0.010913912317997734,0.0013790926164283777'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145753/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.328917233397946,0.9738897191320461,412.6101166944048,3.048222721311272,0.1309143508265523,1.584'
#                     '6269482030788,0.06977386796918922,0.008168058895018133'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-26 15_57.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_145755/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#     ],
#     ensemble_method=ParticleFilter(
#         hyperparameters={
#             'like_sigma_weights': 0.05,
#             'like_sigma_state_vector': 0.01,
#         },
#         N=30,
#         obs=None,
#         state_vectors=None,
#         predictions=None,
#         weights=None,
#         resample_indices=None,
#         new_state_vectors=None,
#     ),
#     ensemble_method_name='PF',
#     observed_variable_name='Q',
#     measurement_operator=<function H at 0x7fa48b5ca830>,
#     observations=(
#         <xarray.DataArray 'Q' (time: 12784)>
#         [12784 values with dtype=float64]
#         Coordinates:
#           * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-12-31
#     ),
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)

time = []
lst_state_vector = []
lst_Q = [] 
for _ in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update(assimilate=True)
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q").flatten())
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1127/1127 [29:41<00:00,  1.58s/it]

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False 
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(sorted(glob.glob(str(output_path/'df_ensemble_*.feather')))[-1]) # read last
    time = list(df_ensemble.index)

# %%
df_ensemble.index
# Out:
# DatetimeIndex(['1997-08-01', '1997-08-02', '1997-08-03', '1997-08-04',
#                '1997-08-05', '1997-08-06', '1997-08-07', '1997-08-08',
#                '1997-08-09', '1997-08-10',
#                ...
#                '2000-08-22', '2000-08-23', '2000-08-24', '2000-08-25',
#                '2000-08-26', '2000-08-27', '2000-08-28', '2000-08-29',
#                '2000-08-30', '2000-08-31'],
#               dtype='datetime64[ns]', length=1127, freq=None)

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])
    time = ds_combined.time.values
    n_particles = len(ds_combined.EnsembleMember)

# %% [markdown]
# ## Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
# ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mea as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"NSe mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
param_names_0 = param_names[:4]
param_names_1 = param_names[4:]

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_0):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_1):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)
