# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     2,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-08-01T00:00:00Z"
experiment_end_date = "2000-09-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle.forcing import sources

# %%
test_forcing = sources.HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'test_forcing.txt',
                          test_data_bool = True 
                          )

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 1

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=1,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     prediction_variable_name=None,
#     observations=None,
#     lst_models_name=[],
#     logger=[],
# )

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[test_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst,
                    state_vector_variables=['all']*n_particles)

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
# ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
# testing data 
ref_model = ensemble.ensemble_list[0].model
ds_obs_dir = forcing_path / ref_model.forcing.pr
ds_obs = xr.load_dataset(ds_obs_dir)

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
ensemble.initialize_method(ensemble_method_name = "PF", 
                           observation_path = ds_obs_dir,
                           observed_variable_name = "Q",
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.005,
                                               }
                            )

# %% [markdown]
# ## Run

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=100,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.153912466282636,0.36792263275583104,356.75808653633584,0.6289369148470008,0.18210847593029808,1'
#                     '.6675137714610746,0.08641281795540652,0.0029989185522154827'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183627/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.3285059417996266,0.8264421845866803,672.1552907634197,0.5280323143034882,0.20082133772705332,1.'
#                     '4697933363105782,0.03648266872483327,0.007744221109545008'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183629/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.116917054505121,0.3383422350793093,256.5720049204517,3.315746510435261,0.1021749069490096,1.608'
#                     '6777925869897,0.04931876184560649,0.004468447987740552'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183630/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.390828055202152,0.5405760820593153,347.59718081563693,1.2656336713016445,0.2566933424278444,1.3'
#                     '632240536715985,0.08646687730015729,0.006640360759786269'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183632/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.5084288518328384,0.5616713602191605,756.8988160246435,2.7010031318743053,0.20624016326433678,1.'
#                     '189596207135354,0.06520350512935087,0.007406774506596649'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183633/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.186814827408238,0.5492909010257577,180.52297751371603,3.573475218395754,0.08366718842533814,1.0'
#                     '678178738892643,0.06368291277154044,0.00795039364197084'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183635/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.036562368721278,0.8094562083455095,414.7056945134322,2.9123536326995745,0.0041720207490262545,1'
#                     '.7856520370692088,0.02650718503498148,0.00725747331343856'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183636/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.676826498273764,0.7264594820546872,612.9498505422151,1.0886285569847003,0.004254941720543703,1.'
#                     '3118570206756321,0.05747137959908347,0.007645142480166735'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183638/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.652133473405526,0.3384277995060535,432.68436700958097,1.383971734531599,0.08115424675580898,1.9'
#                     '774072229332535,0.017885818008662777,0.0012104877600578982'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183639/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.3892934064403892,0.40116567829778105,433.89825030805696,0.6734908022210522,0.131749180706489,1.'
#                     '9553588602790168,0.06791270171104333,0.002553162524902133'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183641/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.7403127497009772,0.9789489841688279,510.31280521549735,2.9037266126602583,0.2712942937072874,1.'
#                     '4915856244202943,0.052893694722379724,0.0018239538191873214'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183642/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.0951762332875905,0.5208154701431396,505.9365373144937,1.9100135083132534,0.19059579431866033,1.'
#                     '2964674454736647,0.07994742662268733,0.004023559316980187'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183644/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.245748018751937,0.3634081857045078,368.8554022933685,0.8581209761703955,0.2993933970583391,1.80'
#                     '24629408952455,0.014901919450688798,0.00993365617991484'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183645/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.596420843641625,0.910489719390924,788.4684279325772,2.089522594424838,0.05554790122253499,1.629'
#                     '9187412480995,0.06854020350073864,0.009674335897337223'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183647/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.931535537897573,0.8392626663344296,764.984198303452,2.1581920058825177,0.028432828609533792,1.6'
#                     '152614294350789,0.06275023100209492,0.0033667120016151295'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183648/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.164998582011557,0.2961943144340962,424.85524355344427,1.0012544658866631,0.17288664482390023,1.'
#                     '2631149428911117,0.07359869314885573,0.004244819879538831'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183650/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.0324881165285067,0.42647222510764693,69.32129563918197,3.472134590331243,0.08806773316432179,1.'
#                     '4229464877646874,0.0341192601302615,0.001643032424914859'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183651/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.7716875403315209,0.48996518643168563,122.36476912170627,2.917334300190616,0.17451197234901053,1'
#                     '.640513320585334,0.05786776957017885,0.009109976399319429'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183653/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.2079032693064589,0.7010519870789005,706.232194441526,1.5764366385838802,0.23266474389007374,1.2'
#                     '944429729261768,0.04408024692302524,0.008606748597935296'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183654/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.4651988902695257,0.5527018341952107,268.4206754539788,2.8809226957700207,0.1828680426282346,1.3'
#                     '633404199448322,0.05964144582671722,0.0006874002092381674'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183656/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.611483641985519,0.22216790093590807,301.85263974950686,3.884438039149816,0.06774431237230634,1.'
#                     '2786878197799172,0.07241569832084369,0.008195084432598553'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183657/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.480209018818906,0.9756903958421799,743.4875766415694,1.1632101465150642,0.17722167182357326,1.3'
#                     '76152371660808,0.011166860147094065,0.0019249120644753434'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183659/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.9346900573399726,0.7256362115071906,755.8257108603389,3.2427142761638463,0.08964963887287465,1.'
#                     '922090916123857,0.09364945921795763,0.0052606686231588306'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183700/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.24323031054446975,0.5837572676490816,279.3984264138968,1.0406714430625068,0.2882695251165862,1.'
#                     '5111955865612128,0.0908838697270855,0.0041550983537582045'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183702/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
# ...
#                 'parameters': (
#                     '2.9831943682236606,0.6187458711290821,601.1038964303051,3.577258680826038,0.2654665508352234,1.28'
#                     '31355982599533,0.05931496582111179,0.00941660673605261'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183848/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.7804119221453076,0.3646702949051888,344.63347576197583,2.9071796199488884,0.19842467610704326,1'
#                     '.7333534329175238,0.020936349387847886,0.009209376820228248'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183850/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.9891878004613766,0.9483216180190233,582.3609991838023,0.518747222459397,0.09609950222903935,1.1'
#                     '968176101221382,0.04453149066871428,0.00943257347053079'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183852/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.768509242216267,0.6665046437244979,67.2162743247541,2.581452160211146,0.16034902712812535,1.440'
#                     '0531266413925,0.015552785399614296,0.008155934540076418'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183853/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.7265988380139197,0.8717478096768139,779.1646710553794,3.9162649580398265,0.056433347712051926,1'
#                     '.2472838541852058,0.03922509993375213,0.004315883517754524'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183855/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.481349492070377,0.8135930691836575,731.0841727750436,1.0200283032985498,0.09311213493770525,1.8'
#                     '30559376168955,0.09159313283412303,0.0024439543674532045'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183856/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.734088465291824,0.857239413832789,307.56607547322676,3.6023198556826244,0.2479355408664454,1.84'
#                     '02891584274044,0.025098025357218078,0.008544912245715129'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183858/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-18 19_38.nc',
#                 pev='HBV_forcing_2024-03-18 19_38.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.559596174151377,0.33099839187855773,596.8415295711746,3.814166607302734,0.015147685790293935,1.'
#                     '291834089624598,0.08670849968376586,0.004251037793014775'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-18 19_38.nc',
#                     pev='HBV_forcing_2024-03-18 19_38.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240318_183859/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#     ],
#     ensemble_method=ParticleFilter(
#         hyperparameters={
#             'like_sigma_weights': 0.05,
#             'like_sigma_state_vector': 0.005,
#         },
#         N=100,
#         obs=None,
#         state_vectors=None,
#         predictions=None,
#         weights=None,
#         resample_indices=None,
#         new_state_vectors=None,
#     ),
#     ensemble_method_name='PF',
#     observed_variable_name='Q',
#     prediction_variable_name='Q',
#     observations=(
#         <xarray.DataArray 'Q' (time: 1127)>
#         [1127 values with dtype=float64]
#         Coordinates:
#           * time     (time) datetime64[ns] 1997-08-01 1997-08-02 ... 2000-08-31
#     ),
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)

time = []
lst_state_vector = []
lst_Q = [] 
for _ in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update()
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q").flatten())
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1126/1126 [1:20:03<00:00,  4.27s/it]

# %% [markdown]
# run 13/03 11:34, 3 years, 30 particles = 27min note: runnning two at once <br>
# run 13/03 11:46, 1 year, 1 particle = 1 min <br>
# run 13/03 12:01, 1 year, 35 particles = 10min <br>
# run 13/03 13:13, 1 year, 100 particles = 31min <br>
# run 13/03 14:30, 1 year, 100 particles = 25min (EnKF) <br>
# run 13/03 14:45, 1 year, 200 particles = 1hr?min  <br>

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, True 
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(sorted(glob.glob(str(output_path/'df_ensemble_*.feather')))[-1]) # read last
    time = list(df_ensemble.index)

# %%
df_ensemble.index
# Out:
# DatetimeIndex(['1997-08-01', '1997-08-02', '1997-08-03', '1997-08-04',
#                '1997-08-05', '1997-08-06', '1997-08-07', '1997-08-08',
#                '1997-08-09', '1997-08-10',
#                ...
#                '2000-08-21', '2000-08-22', '2000-08-23', '2000-08-24',
#                '2000-08-25', '2000-08-26', '2000-08-27', '2000-08-28',
#                '2000-08-29', '2000-08-30'],
#               dtype='datetime64[ns]', length=1126, freq=None)

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])
    time = ds_combined.time.values
    n_particles = len(ds_combined.EnsembleMember)

# %% [markdown]
# ## Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
# ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mea as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"NSe mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
param_names_0 = param_names[:4]
param_names_1 = param_names[4:]

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_0):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_1):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)
