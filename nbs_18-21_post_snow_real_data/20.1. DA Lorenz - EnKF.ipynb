# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-lorenz

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
experiment_start_date = "1997-10-01T00:00:00Z"
experiment_end_date = "1997-10-05T00:00:00Z"

# %%
from ewatercycle.forcing import sources

# %%
lorenz_forcing = sources.LorenzForcing(start_time = experiment_start_date,
                                      end_time = experiment_end_date,
                                      directory = forcing_path,
                                      F = 8,
                                      dt=1e-3
                          )

# %% [markdown]
# #### import model

# %%
# from ewatercycle.models import Lorenz

# %% [markdown]
# #### import DA function:

# %%
# pip uninstall ewatercycle_DA -y

# %%
# pip install git+https://github.com/Daafip/eWaterCycle-DA@dev

# %%
from ewatercycle_DA import DA
from ewatercycle_DA.local_models import lorenz

# %%
# import importlib.util

# def module_from_file(module_name, file_path):
#     spec = importlib.util.spec_from_file_location(module_name, file_path)
#     module = importlib.util.module_from_spec(spec)
#     spec.loader.exec_module(module)
#     return module

# %%
# DA = module_from_file("DA",r'../eWaterCycle-DA/src/ewatercycle_DA/DA.py')

# %%
# lorenz = module_from_file("lorenz",r'../eWaterCycle-DA/src/ewatercycle_DA/lorenz.py')

# %%
n_particles = 200

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
J = 4
common_state = np.zeros(J)
common_state[0] = 0.01

# %% [markdown]
# ### petrub state every so slightly to start with:

# %%
rng = np.random.default_rng()
def add_normal_noise(like_sigma) -> float:
    """Normal (zero-mean) noise to be added to a state

    Args:
        like_sigma (float): scale parameter - pseudo variance & thus 'like'-sigma

    Returns:
        sample from normal distribution
    """
    return rng.normal(loc=0, scale=like_sigma)  # log normal so can't go to 0 ?

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    peturbed_state = common_state.copy()
    peturbed_state[0] += add_normal_noise(0.05)
    setup_kwargs_lst.append({'J':J, 
                            'start_state':list(peturbed_state),
                             })

# %%
ensemble.initialize(model_name=["LorenzLocal"]*n_particles,
                    forcing=[lorenz_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst)

# %%
pprint(ensemble.ensemble_list)
# Out:
# [
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.008087511596456905,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.004194677030187248,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.03173407401613548,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.03723375972091592,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.0423716040086617,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.026936525194469485,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.05154915111002528,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.06333636223538228,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.029629628235668656,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.00619146606806943,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.06516160507205025,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.022794981160774278,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.08331045446930616,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.05563189405618405,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.036607220216098475,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.10243073649253574,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.006080066216918775,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.06053232440098961,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.09068456610484463,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.029938834217696414,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.11302138895227765,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.04411550710631935,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.02996300491556629,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.021659453777887736,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.015257803708842674,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.011673296908577732,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.02492698930456142,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.057342148264926,
#                 0.0,
# ...
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.10863847567924952,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.030457920089251668,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.08752079538014614,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.09750860084005307,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.020257897598256247,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.020137238493053038,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 0.06148831832663199,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.011774162606941268,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-05T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 4,
#             'start_state': [
#                 -0.0356028437638146,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-05T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240416_100329/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'ewatercycle_DA.local_models.lorenz.LorenzLocal'>,
#         },
#     ),
# ]

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````
#
# `%SystemRoot%\system32\WindowsPowerShell\v1.0\powershell.exe`

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## run truth model as observations

# %%
truth_model = lorenz.LorenzLocal(forcing=lorenz_forcing)
config, _ = truth_model.setup(J=J,
                        start_state=list(common_state))
truth_model.initialize(config)

# %%
n_timesteps = int(round((truth_model.end_time - truth_model.start_time) /  truth_model.time_step,0))

output = pd.DataFrame(columns =['truth'])
output_lst = []

for _ in tqdm(range(n_timesteps)):   
    truth_model.update()
    output.loc[truth_model.time_as_datetime] = truth_model.get_value("state")[0]
    output_lst.append(truth_model.get_value("state"))
truth_model.finalize()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4000/4000 [00:04<00:00, 986.44it/s]

# %%
output.index.name = "time"
current_time = str(datetime.now())[:-10].replace(":","_")
ds_obs_dir = observations_path / f'truth_model_lorenz96_{current_time}.nc'
# ds_obs = xr.Dataset(data_vars=output[['truth']])
ds_all = xr.Dataset({'truth':xr.DataArray(data=pd.DataFrame(output_lst,index=output.index),dims=["time","x"])})
ds_obs = ds_all.sel(x=[1])
# ds_obs = xr.Dataset({'truth':xr.DataArray(data=pd.DataFrame(output,index=output.index),dims=["time","x"])})
ds_obs.to_netcdf(ds_obs_dir)

# %% [markdown]
# Highly chaotic system

# %%
for i in ds_all.x:
    all = ds_all['truth'].sel(x=i).plot(color="C0",label="all");
for i in ds_obs.x:
    observed = ds_obs['truth'].sel(x=i).plot(color="C1",label='observed',ls="--");
plt.legend(handles=all+observed);

# %%
output_arr = np.array(output_lst)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot(output_arr[:, 0],output_arr[:, 1], output_arr[:, 2])
ax.set_xlabel("$x_1$")
ax.set_ylabel("$x_2$")
ax.set_zlabel("$x_3$")
plt.show()

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
def H(Z):
    """Function which takes the state vector Z and returns part of that state. Returned should be same shape as data provided"""
    if len(Z) == J:
        return Z[1]
    else: 
        raise SyntaxWarning(f"Length of statevector should be {J} but is {len(Z)}")

# %%
ensemble.initialize_da_method(ensemble_method_name = "EnKF", 
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.05,
                                               'observed_state_index': 1,
                                               },
                           state_vector_variables = ["state"],
                           observation_path = ds_obs_dir,
                           observed_variable_name = "truth",
                           measurement_operator= H                           
                            )

# %% [markdown]
# # Run

# %%
ref_model = ensemble.ensemble_list[0].model

# %%
assimilation_window = 100

# %%
n_timesteps = int(round((ref_model.end_time - ref_model.start_time) /  ref_model.time_step,0))
time = []
lst_state_vector = []
lst_Q = [] 
for i in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    if i < 1500:
        assimilate = False
    else:
        if i % assimilation_window == 0:  
            assimilate = True
        else:                             
            assimilate = False
    ensemble.update(assimilate)
    lst_state_vector.append(ensemble.get_state_vector())
    # lst_Q.append(ensemble.get_value("state"))
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 4000/4000 [06:34<00:00, 10.15it/s]

# %%
rng = np.random.default_rng() # Initiate a Random Number Generator
def add_normal_noise(like_sigma) -> float:
    """Normal (zero-mean) noise to be added to a state

    Args:
        like_sigma (float): scale parameter - pseudo variance & thus 'like'-sigma

    Returns:
        sample from normal distribution
    """
    return rng.normal(loc=0, scale=like_sigma)  # log normal so can't go to 0 ?

# %%
np.matrix(ensemble.ensemble_method.predictions).shape
# Out:
# (200, 1)

# %%
# ensemble.update(assimilate=True)

# %%
self = ensemble.ensemble_method

# %%
self.state_vectors.shape
# Out:
# (200, 4)

# %%
# self.state_vectors[0][2:4]

# %%
self.obs
# Out:
# array([1.59556847])

# %%
n = 1

# %%
measurement_d = np.matrix(self.obs[:n]).T

# %%
measurement_d
# Out:
# matrix([[1.59556847]])

# %%
measurement_pertubation_matrix_E = np.array([[add_normal_noise(1)]*measurement_d.shape[0] for _ in range(self.N)]).T

# %%
measurement_pertubation_matrix_E.shape
# Out:
# (1, 200)

# %%
peturbed_measurements_D = measurement_d * np.matrix(np.ones(self.N).T) + np.sqrt(
                                                                self.N - 1) * measurement_pertubation_matrix_E

# %%
peturbed_measurements_D.shape
# Out:
# (1, 200)

# %%
predicted_measurements_Ypsilon = np.matrix(self.predictions[:,:n]a).T
# Out:
#   Cell In[50], line 1
#     predicted_measurements_Ypsilon = np.matrix(self.predictions[:,:n]a).T
#                                                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
predicted_measurements_Ypsilon.shape

# %%
prior_state_vector_Z = self.state_vectors.T

PI = np.matrix((np.identity(self.N) - ((np.ones(self.N) @ np.ones(self.N).T) / self.N)) / (
    np.sqrt(self.N - 1)))
A_cross_A = np.matrix(
    (np.identity(self.N) - ((np.ones(self.N) @ np.ones(self.N).T) / self.N)))


E = np.matrix(peturbed_measurements_D) * PI

Y = np.matrix(predicted_measurements_Ypsilon) * PI
if prior_state_vector_Z.shape[0] < self.N - 1:
    Y = Y * A_cross_A
S = Y
D_tilde = peturbed_measurements_D - predicted_measurements_Ypsilon

# %%
peturbed_measurements_D.shape

# %%
predicted_measurements_Ypsilon.shape

# %%
D_tilde.shape

# %%
W = (S.T * np.linalg.inv(S * S.T + E * E.T)) * D_tilde

# %%
W = (S.T * np.linalg.inv(S * S.T + E * E.T)) * D_tilde
T = np.identity(self.N) + (W / np.sqrt(self.N - 1))

# %%
T.shape

# %%
prior_state_vector_Z[n,:] = (prior_state_vector_Z[n,:] * T)

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False
current_time = str(datetime.now())[:-10].replace(":","_")

# %% [markdown]
# ### process states and parameters into xarrys

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(range(J)):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),time[:len(state_vector_arr)]],
                                      attrs={"title": f"Lorenz states over time for {n_particles} particles ", 
                                               "history": f"states of lorenz model: ewatercycle DA",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"Lorenz model over time for {n_particles} particles ", 
                                    "history": f"states of lorenz model: ewatercycle DA",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])

# %% [markdown]
# ## Plotting

# %%
save = False

# %%
# ds_combined[x].isel(EnsembleMember=i).values

# %%
ds_obs['truth']
# Out:
# <xarray.DataArray 'truth' (time: 4000, x: 1)>
# array([[0.007996  ],
#        [0.01598401],
#        [0.02396404],
#        ...,
#        [1.58227373],
#        [1.58352756],
#        [1.58480353]])
# Coordinates:
#   * time     (time) datetime64[ns] 1997-10-01T00:01:26 ... 1997-10-04T23:59:59
#   * x        (x) int64 1

# %%
# ds_obs['truth'].plot(zorder=1,color="C1")
plt.plot(list(output.index), ds_combined[3].isel(EnsembleMember=i).values)

# %%
fig, ax = plt.subplots(1,1,figsize=(12,5))
x = 3
for i in range(n_particles):
    # ds_combined[7].isel(EnsembleMember=i).plot(ax=ax)
    plt.plot(list(output.index)[:len(ds_combined[x].isel(EnsembleMember=i).values)],ds_combined[x].isel(EnsembleMember=i),lw=0.5,color='C0',zorder=-1)
# for x in range(J):
# ds_obs['truth'].sel(x=x).plot(zorder=1,color="C1")
ds_obs['truth'].plot(zorder=1,color="C1")
ax.set_title(f"Lorenz model with particle filter, assimilating every {assimilation_window} steps for {n_particles} ensemble members")
# if save: 
    # fig.savefig(figure_path / "lorenz_model.png",bbox_inches="tight",dpi=400)
# Out:
# Text(0.5, 1.0, 'Lorenz model with particle filter, assimilating every 100 steps for 200 ensemble members')

# %%
fig, ax = plt.subplots(1,1,figsize=(12,5))
x = 2
for i in range(n_particles):
    # ds_combined[7].isel(EnsembleMember=i).plot(ax=ax)
    plt.plot(list(output.index)[:len(ds_combined[x].isel(EnsembleMember=i).values)],ds_combined[x].isel(EnsembleMember=i),lw=0.5,color='C0',zorder=-1)
# for x in range(J):
# ds_obs['truth'].sel(x=x).plot(zorder=1,color="C1")
ds_obs['truth'].plot(zorder=1,color="C1")
ax.set_title(f"Lorenz model with particle filter, assimilating every {assimilation_window} steps for {n_particles} ensemble members")
if save: 
    fig.savefig(figure_path / "lorenz_model.png",bbox_inches="tight",dpi=400)
