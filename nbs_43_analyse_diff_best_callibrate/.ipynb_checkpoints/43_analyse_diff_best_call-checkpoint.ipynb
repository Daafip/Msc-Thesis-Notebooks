# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
from datetime import datetime
from datetime import timedelta
import matplotlib.cm as cm

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qo - Qm)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)
    
def calc_log_NSE(Qo, Qm):
    Qo[Qo == 0] = 1e-6
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((np.log(Qo) - np.log(Qm))**2)
    ErrDo = np.sum((np.log(Qo) - np.log(QoAv))**2)
    return 1 - (ErrUp / ErrDo)

# %%
path = Path.cwd()

# %%
best_ds_files = list((path.parent / "nbs_42_also_store_Q_best" / 'Output').glob("*.nc"))

# %%
best_ds_lst = []
for file in best_ds_files:
    best_ds_lst.append(xr.open_dataset(file))

# %%
df_best = pd.DataFrame(columns=["NSE_mean","NSE_mean_log","NSE_best","NSE_best_log","path"],)
for ds in best_ds_lst:
    uid = ds.attrs['HRU_id']
    df_best.loc[uid, 'NSE_mean'] = calc_NSE(ds["Q_obs"].values, ds["Q"].sel(summary_stat="mean").values)
    df_best.loc[uid, 'NSE_mean_log'] = calc_log_NSE(ds["Q_obs"].values, ds["Q"].sel(summary_stat="mean").values)
    df_best.loc[uid, 'NSE_best'] = calc_NSE(ds["Q_obs"].values, ds["Q"].sel(summary_stat="best").values)
    df_best.loc[uid, 'NSE_best_log'] = calc_log_NSE(ds["Q_obs"].values, ds["Q"].sel(summary_stat="best").values)
    df_best.loc[uid,'path'] = file

# %%
df_best
# Out:
#           NSE_mean NSE_mean_log  NSE_best NSE_best_log  \
# 01078000  0.561461     0.487625  0.773989     0.730695
# 01013500   0.57813     -0.55511  0.861828     0.662818
# 01022500  0.521113     0.541622  0.655206     0.706836
# 01030500   0.15002     0.319357  0.412902     0.476651
# 01031500  0.546325      0.53221  0.628023     0.621102
# 01047000  0.515318     0.644361  0.571648     0.713966
# 01052500 -0.770808    -0.534901 -0.303559    -0.155364
# 01054200  0.293753     0.311727  0.433753     0.423951
# 01055000  0.289401     0.181397  0.580459     0.544982
# 01057000  0.519431     0.531134  0.654761     0.652635
# 01073000  0.650791     0.683696    0.8968      0.88347
# 01118300  0.277024     0.510453  0.364793     0.639735
# 01121000  0.208147     0.421264  0.355926     0.664325
# 01123000  0.173075     0.160316  0.454101     0.642864
# 01134500  0.295294     0.124113  0.571524     0.501229
# 01137500  0.211852     -0.29934  0.489853     0.469074
# 01139000  0.469594     0.314769   0.78462     0.797514
# 01139800  0.550378     0.330018  0.878817     0.818847
# 01142500  0.581104      0.59185  0.701078     0.739513
# 01144000  0.487658     0.497836  0.678028     0.763804
# 01162500  0.600067     0.420583  0.769548     0.593543
# 01169000  0.422516     0.623636  0.496417     0.732764
# 01170100  0.420046     0.449745  0.545684     0.654363
# 01181000  0.386499     0.552198  0.533813     0.742403
# 01187300  0.283336      0.27162  0.346984     0.364462
# 04296000  0.200954     0.084691  0.538894     0.781896
#
#                                                        path
# 01078000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01013500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01022500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01030500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01031500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01047000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01052500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01054200  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01055000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01057000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01073000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01118300  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01121000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01123000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01134500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01137500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01139000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01139800  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01142500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01144000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01162500  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01169000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01170100  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01181000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 01187300  /media/davidhaasnoot/files/work/Studie TUD/Msc...
# 04296000  /media/davidhaasnoot/files/work/Studie TUD/Msc...
