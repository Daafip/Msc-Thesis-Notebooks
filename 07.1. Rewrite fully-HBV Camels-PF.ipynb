# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     2,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-08-01T00:00:00Z"
experiment_end_date = "2000-09-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle.forcing import sources

# %%
camels_forcing = sources.HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'0{HRU_id}_lump_cida_forcing_leap.txt',
                          alpha = alpha
                          )

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 30

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     prediction_variable_name=None,
#     observations=None,
#     lst_models_name=[],
#     logger=[],
# )

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[camels_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst,
                    state_vector_variables=['all']*n_particles)

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
observations = observations_path / f'0{HRU_id}_streamflow_qc.txt'

# %%
cubic_ft_to_cubic_m = 0.0283168466

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %%
new_header = ['GAGEID','Year','Month', 'Day', 'Streamflow(cubic feet per second)','QC_flag']
new_header_dict = dict(list(zip(range(len(new_header)),new_header)))

df_Q = pd.read_fwf(observations,delimiter=' ',encoding='utf-8',header=None)
df_Q = df_Q.rename(columns=new_header_dict)
df_Q['Streamflow(cubic feet per second)'] = df_Q['Streamflow(cubic feet per second)'].apply(lambda x: np.nan if x==-999.00 else x)
df_Q['Q (m3/s)'] = df_Q['Streamflow(cubic feet per second)'] * cubic_ft_to_cubic_m
df_Q['Q'] = df_Q['Q (m3/s)'] / ds.attrs['area basin(m^2)'] * 3600 * 24 * 1000 # m3/s -> m/s ->m/d -> mm/d
df_Q.index = df_Q.apply(lambda x: pd.Timestamp(f'{int(x.Year)}-{int(x.Month)}-{int(x.Day)}'),axis=1)
df_Q.index.name = "time"
df_Q.drop(columns=['Year','Month', 'Day','Streamflow(cubic feet per second)'],inplace=True)
df_Q = df_Q.dropna(axis=0)

ds_obs_dir = observations_path / f'0{HRU_id}_streamflow_qc.nc'
ds_obs = xr.Dataset(data_vars=df_Q[['Q']])
if not ds_obs_dir.exists():
    ds_obs.to_netcdf(ds_obs_dir)

# %%
ax = df_Q['Q'].plot()
ax.set_xlim((pd.Timestamp(experiment_start_date),pd.Timestamp(experiment_end_date)))
ax.set_ylabel("Q (mm/d)")
ax.set_title("observations");

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
ensemble.initialize_method(ensemble_method_name = "PF", 
                           observation_path = ds_obs_dir,
                           observed_variable_name = "Q",
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.005,
                                               }
                            )

# %% [markdown]
# ## Run

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.7107946489096042,0.2934741967707809,514.5985143622661,2.1105264444212164,0.07209726403558682,1.'
#                     '6500806044560803,0.0348037258822603,0.003943994479844858'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100349/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.1981701962849955,0.801189699922003,640.8831804492769,2.005628680579691,0.19901812717337353,1.79'
#                     '44585172685736,0.05333955411412143,0.004141084596473635'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100350/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.3308461759459913,0.21408762119463942,101.5242698979796,2.224813341421992,0.052812879881363455,1'
#                     '.7648093611081646,0.06953520729763386,0.0053603592456821034'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100352/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.06159987469366,0.44826653238343717,603.3817073283642,3.5026977511873016,0.044097995004104155,1.'
#                     '8306712939353593,0.01922065966189515,0.00700030264185647'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100353/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.720062098279869,0.548818611357037,571.4816023321564,2.398288487995597,0.04288671414256614,1.454'
#                     '760413280467,0.08377637481161805,0.0021588928941832382'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100355/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.366290312187842,0.7667345158168899,432.1293653186295,2.1405757455719367,0.20036499582597814,1.8'
#                     '017295290344528,0.09715924599612842,0.0010475201299595014'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100357/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.620377557717481,0.3255312135307734,75.32223007606551,3.8063698452416608,0.28180381634837787,1.1'
#                     '935158869605986,0.08560807204516332,0.0010203648821882675'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100358/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.674999089967716,0.3728359736647904,69.93419297564932,0.5703328193858148,0.21453915205139035,1.2'
#                     '374065344566405,0.040260725035355056,0.0073975020550767516'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100400/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.06149826378772172,0.996083220216136,57.52517854674801,3.7268451308820074,0.09721133711769474,1.'
#                     '6693009564999794,0.011460551824652027,0.006938658341259367'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100401/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.7485513488645736,0.8882358846917537,94.41053090009788,1.9549349914625989,0.02660293010234789,1.'
#                     '543493482003056,0.018386463269601416,0.009578116128363338'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100403/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.670057612033289,0.41738115122345604,623.2798251967359,1.1618667186788734,0.008424550405625817,1'
#                     '.6402999296134662,0.07788178276428333,0.005208722541253491'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100404/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.566308033243916,0.5677555156175988,336.1373289509775,2.722502833441062,0.2713975947164792,1.286'
#                     '9379205364655,0.08348316550276755,0.0088930885315795'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100406/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.068434358373429,0.23919964098891625,635.3203313283879,3.8109691416921607,0.013199561870637467,1'
#                     '.9228683071210992,0.03662468101134039,0.005241367699639365'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100408/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.6032168257762383,0.49484575515920437,243.65590220923528,1.718232370575654,0.15972204659251005,1'
#                     '.635648998639901,0.029648478953370395,0.003437483403148771'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100409/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.386682050131908,0.22106300659366562,161.80789516532252,1.9490247843227275,0.16594086485869325,1'
#                     '.255206710636394,0.08936162097987868,0.0007506007748780477'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100411/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.4053216984892405,0.6853736170879987,362.97781934773735,3.9230273161903795,0.22374705839870748,1'
#                     '.972742427190357,0.026885174181115537,0.004881805461128103'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100412/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.594963505062089,0.3261284600829599,601.8515685915155,1.828683425917856,0.2104534805442951,1.785'
#                     '6380948235877,0.08010279124321924,0.00010363259580830901'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100414/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.745202914334528,0.4126237249127737,606.6057975256277,2.0418870146711536,0.011671487820496821,1.'
#                     '4759103282427348,0.022032501984062626,0.0026779467572342584'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100416/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.110619962361888,0.8855745808752931,728.1132309363828,1.768769222347286,0.16395516960154055,1.33'
#                     '95928626947362,0.06164572211660369,0.008431812275540249'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100417/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.849956663454976,0.3992846722222432,769.3980313274195,2.628562351191885,0.14275587392254258,1.08'
#                     '2827501443198,0.04194134569748871,0.001703802897850294'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100419/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.574434779294927,0.3740642571346016,561.0948370899131,0.8974009318649854,0.1628528354775837,1.55'
#                     '18496551893293,0.021148399820867966,0.005648490522550167'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100420/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.13665561758863465,0.7565846573939137,401.6091664112285,3.2397885162587636,0.15066131890796292,1'
#                     '.3638024308076462,0.01620909404339572,0.004808568537127431'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100422/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.7205990910681885,0.9077890206596704,539.3426336816428,2.2593441534072856,0.21180034716154894,1.'
#                     '0731505497269684,0.06522741762706756,0.006061432695320684'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100423/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.371134426172649,0.8676721665023173,639.4434395036627,1.6668983972727527,0.04898262413561014,1.7'
#                     '521954446893122,0.0838465097390898,0.002200085982459983'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100425/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.2168482779636953,0.6917468084784449,54.361943791909304,2.650482884108036,0.06555699559570306,1.'
#                     '908064591966696,0.09552975769275775,0.0050744882404246735'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100427/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.327580192702114,0.5721131957919942,162.16299158527528,2.1784659485162656,0.003333623874532536,1'
#                     '.994554823727769,0.09165230793283083,0.007057927143511851'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100428/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.766965131928511,0.9865181011966155,647.3567874415319,2.6985471314374356,0.022534379530100193,1.'
#                     '6105332390614706,0.03407615205029289,0.0008963619295166351'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100430/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.49027359797281,0.839668238425866,474.76130595302095,2.1554348278286035,0.09208890858993103,1.19'
#                     '33592033438676,0.07697407804260184,0.005869222103333228'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100431/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.632634228225772,0.32541968760093565,348.16626626094234,1.0453119522724756,0.17525760450983008,1'
#                     '.1577458187097438,0.09952667451591503,0.008968985360404394'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100433/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.750659412712584,0.9170372415302122,490.94717403032513,1.9448173392361803,0.016433336750822848,1'
#                     '.9507811325912976,0.0648398037073861,0.003240454167477014'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 11_04.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_100435/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#     ],
#     ensemble_method=ParticleFilter(
#         hyperparameters={
#             'like_sigma_weights': 0.05,
#             'like_sigma_state_vector': 0.005,
#         },
#         N=30,
#         obs=None,
#         state_vectors=None,
#         predictions=None,
#         weights=None,
#         resample_indices=None,
#         new_state_vectors=None,
#     ),
#     ensemble_method_name='PF',
#     observed_variable_name='Q',
#     prediction_variable_name='Q',
#     observations=(
#         <xarray.DataArray 'Q' (time: 12784)>
#         [12784 values with dtype=float64]
#         Coordinates:
#           * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-12-31
#     ),
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)

time = []
lst_state_vector = []
lst_Q = [] 
for _ in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update()
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q").flatten())
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
#  24%|███████████████████▍                                                            | 273/1127 [06:09<18:25,  1.29s/it]

# %% [markdown]
# run 13/03 11:34, 3 years, 30 particles = 27min note: runnning two at once <br>
# run 13/03 11:46, 1 year, 1 particle = 1 min <br>
# run 13/03 12:01, 1 year, 35 particles = 10min <br>
# run 13/03 13:13, 1 year, 100 particles = 31min <br>
# run 13/03 14:30, 1 year, 100 particles = 25min (EnKF) <br>
# run 13/03 14:45, 1 year, 200 particles = 1hr?min  <br>

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, True 
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(sorted(glob.glob(str(output_path/'df_ensemble_*.feather')))[-1]) # read last
    time = list(df_ensemble.index)

# %%
df_ensemble.index

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])
    time = ds_combined.time.values
    n_particles = len(ds_combined.EnsembleMember)

# %% [markdown]
# ## Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
# ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mea as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"NSe mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
param_names_0 = param_names[:4]
param_names_1 = param_names[4:]

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_0):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_1):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)
