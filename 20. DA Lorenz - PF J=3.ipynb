# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-lorenz

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
experiment_start_date = "1997-10-01T00:00:00Z"
experiment_end_date = "1997-10-06T00:00:00Z"

# %%
from ewatercycle.forcing import sources

# %%
lorenz_forcing = sources.LorenzForcing(start_time = experiment_start_date,
                                      end_time = experiment_end_date,
                                      directory = forcing_path,
                                      F = 8,
                                      dt=1e-3
                          )

# %% [markdown]
# #### import model

# %%
# from ewatercycle.models import Lorenz

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/ewatercycle_DA/DA.py')

# %%
lorenz = module_from_file("lorenz",r'../eWaterCycle-DA/src/ewatercycle_DA/lorenz.py')

# %%
n_particles = 50

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
J = 5
common_state = np.zeros(J)
common_state[1] = 0.01

# %% [markdown]
# ### petrub state every so slightly to start with:

# %%
rng = np.random.default_rng()
def add_normal_noise(like_sigma) -> float:
    """Normal (zero-mean) noise to be added to a state

    Args:
        like_sigma (float): scale parameter - pseudo variance & thus 'like'-sigma

    Returns:
        sample from normal distribution
    """
    return rng.normal(loc=0, scale=like_sigma)  # log normal so can't go to 0 ?

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    peturbed_state = common_state.copy()
    peturbed_state[1] += add_normal_noise(0.01)
    setup_kwargs_lst.append({'J':J, 
                            'start_state':list(peturbed_state),
                             })

# %%
ensemble.initialize(model_name=["LorenzLocal"]*n_particles,
                    forcing=[lorenz_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst)

# %%
pprint(ensemble.ensemble_list)
# Out:
# [
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.007961238328768381,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.009640455310386419,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.0003660450871165264,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.01531952417629721,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.01573800447438215,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.019162968044988224,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.013411099889999365,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.019736952348468444,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.017189035812144045,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.012117803042773547,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.002034768216014591,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.005029962699544562,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 -0.009365796182831164,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.01915030764391889,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.001747052182582037,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.022201219722450035,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 -0.003992832970294673,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.004488765063284961,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.0008083429277170647,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.00804959264621094,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.008989980897839329,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.03525582215042045,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.029089564104195012,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 -0.003961745357094577,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.008823300219541268,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.009332784168493874,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.016170799741179704,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.012903518706820247,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
# ...
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 -0.006232216675665028,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.017422181662763794,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.011052385450347953,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.018187399374963026,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.009712826687032168,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 -0.00578584130330167,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.026049124742691318,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 0.0360188940967671,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
#     EnsembleMember(
#         model_name='LorenzLocal',
#         forcing=LorenzForcing(
#             start_time='1997-10-01T00:00:00Z',
#             end_time='1997-10-06T00:00:00Z',
#             directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#             shape=None,
#             filenames={},
#             F=8.0,
#             dt=0.001,
#         ),
#         setup_kwargs={
#             'J': 5,
#             'start_state': [
#                 0.0,
#                 -0.0152160003290124,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#         },
#         state_vector_variables=None,
#         model=LorenzLocal(
#             parameter_set=None,
#             forcing=LorenzForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1997-10-06T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 filenames={},
#                 F=8.0,
#                 dt=0.001,
#             ),
#         ),
#         config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/lorenzlocal_20240408_132628/lorenz_config.json',
#         state_vector=None,
#         variable_names=None,
#         loaded_models={
#             'Lorenz': <class 'ewatercycle_lorenz.model.Lorenz'>,
#             'MarrmotM01': <class 'ewatercycle_marrmot.model.MarrmotM01'>,
#             'MarrmotM14': <class 'ewatercycle_marrmot.model.MarrmotM14'>,
#             'LeakyBucket': <class 'ewatercycle_leakybucket.model.LeakyBucket'>,
#             'ParallelisationSleep': <class 'ewatercycle_parallelisation_sleep.model.ParallelisationSleep'>,
#             'HBV': <class 'ewatercycle_HBV.model.HBV'>,
#             'LorenzLocal': <class 'lorenz.LorenzLocal'>,
#         },
#     ),
# ]

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````
#
# `%SystemRoot%\system32\WindowsPowerShell\v1.0\powershell.exe`

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## run truth model as observations

# %%
truth_model = lorenz.LorenzLocal(forcing=lorenz_forcing)
config, _ = truth_model.setup(J=J,
                        start_state=list(common_state))
truth_model.initialize(config)

# %%
n_timesteps = int(round((truth_model.end_time - truth_model.start_time) /  truth_model.time_step,0))

output = pd.DataFrame(columns =['truth'])
output_lst = []

for _ in tqdm(range(n_timesteps)):   
    truth_model.update()
    output.loc[truth_model.time_as_datetime] = truth_model.get_value("state")[3]
    output_lst.append(truth_model.get_value("state"))
truth_model.finalize()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:08<00:00, 556.29it/s]

# %%
output.index.name = "time"
current_time = str(datetime.now())[:-10].replace(":","_")
ds_obs_dir = observations_path / f'truth_model_lorenz96_{current_time}.nc'
# ds_obs = xr.Dataset(data_vars=output[['truth']])
ds_all = xr.Dataset({'truth':xr.DataArray(data=pd.DataFrame(output_lst,index=output.index),dims=["time","x"])})
ds_obs = xr.Dataset({'truth':xr.DataArray(data=pd.DataFrame(output,index=output.index),dims=["time","x"])})
ds_obs.to_netcdf(ds_obs_dir)

# %% [markdown]
# Highly chaotic system

# %%
for i in range(5):
    ds_all['truth'].isel(x=i).plot(color="C0");
# ds_obs['truth'].plot(color="C1");
ds_all['truth'].isel(x=3).plot(color="C1");

# %%
output_arr = np.array(output_lst)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot(output_arr[:, 1],output_arr[:, 2], output_arr[:, 3])
ax.set_xlabel("$x_1$")
ax.set_ylabel("$x_2$")
ax.set_zlabel("$x_3$")
plt.show()

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
def H(Z):
    """Function which takes the state vector Z and returns part of that state. Returned should be same shape as data provided"""
    if len(Z) == J:
        return Z[2] 
    else: 
        raise SyntaxWarning(f"Length of statevector should be {J} but is {len(Z)}")

# %%
ensemble.initialize_da_method(ensemble_method_name = "PF", 
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 1.0,
                                               },
                           state_vector_variables = ["state"],
                           observation_path = ds_obs_dir,
                           observed_variable_name = "truth",
                           measurement_operator= H                           
                            )

# %% [markdown]
# # Run

# %%
ref_model = ensemble.ensemble_list[0].model

# %%
assimilation_window = 50

# %%
n_timesteps = int(round((ref_model.end_time - ref_model.start_time) /  ref_model.time_step,0))
time = []
lst_state_vector = []
lst_obj_prior = []
lst_obj_post = []
for i in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    lst_obj_prior.append(ensemble.get_state_vector()[3])
    if i % assimilation_window == 0:  assimilate = True
    else:                             assimilate = False
    ensemble.update(assimilate)
    lst_obj_post.append(ensemble.get_state_vector()[3])
    lst_state_vector.append(ensemble.get_state_vector())
    # lst_Q.append(ensemble.get_value("state"))
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 5000/5000 [05:52<00:00, 14.17it/s]

# %%
arr_prior = np.array(lst_obj_prior).T
arr_post = np.array(lst_obj_post).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False
current_time = str(datetime.now())[:-10].replace(":","_")

# %% [markdown]
# ### process states and parameters into xarrys

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(range(J)):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),time[:len(state_vector_arr)]],
                                      attrs={"title": f"Lorenz states over time for {n_particles} particles ", 
                                               "history": f"states of lorenz model: ewatercycle DA",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"Lorenz model over time for {n_particles} particles ", 
                                    "history": f"states of lorenz model: ewatercycle DA",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])

# %% [markdown]
# ## Plotting

# %%
save = True

# %%
fig, ax = plt.subplots(1,1,figsize=(12,5))
x = 3
for i in range(n_particles):
    # ds_combined[7].isel(EnsembleMember=i).plot(ax=ax)
    plt.plot(list(output.index)[:len(ds_combined[x].isel(EnsembleMember=i).values)],ds_combined[x].isel(EnsembleMember=i),lw=0.5,color='C0',zorder=-1)
# for x in range(J):
ds_obs['truth'].plot(zorder=1,color="C1")
ax.set_title(f"Lorenz model with particle filter, assimilating every {assimilation_window} steps for {n_particles} ensemble members")
# if save: 
    # fig.savefig(figure_path / "lorenz_model.png",bbox_inches="tight",dpi=400)
# Out:
# Text(0.5, 1.0, 'Lorenz model with particle filter, assimilating every 50 steps for 50 ensemble members')

# %%
fig, ax = plt.subplots(1,1,figsize=(12,5))
x = 4
for i in range(n_particles):
    # ds_combined[7].isel(EnsembleMember=i).plot(ax=ax)
    plt.plot(list(output.index)[:len(ds_combined[x].isel(EnsembleMember=i).values)],ds_combined[x].isel(EnsembleMember=i),lw=0.5,color='C0',zorder=-1)
# for x in range(J):
ds_obs['truth'].plot(zorder=1,color="C1")
ax.set_title(f"Lorenz model with particle filter, assimilating every {assimilation_window} steps for {n_particles} ensemble members")
if save: 
    fig.savefig(figure_path / "lorenz_model.png",bbox_inches="tight",dpi=400)
