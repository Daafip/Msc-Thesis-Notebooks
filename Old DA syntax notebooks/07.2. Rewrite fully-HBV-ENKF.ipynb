# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime 
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     10,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-08-01T00:00:00Z"
experiment_end_date = "2000-09-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle.forcing import sources

# %%
# camels_forcing = sources.HBVForcing(start_time = experiment_start_date,
#                           end_time = experiment_end_date,
#                           directory = forcing_path,
#                           camels_file = f'0{HRU_id}_lump_cida_forcing_leap.txt',
#                           alpha = alpha
#                           )

# %%
camels_forcing = sources.HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'test_forcing.txt',
                          test_data_bool = True 
                          )

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 50

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=50,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     prediction_variable_name=None,
#     observations=None,
#     lst_models_name=[],
#     logger=[],
# )

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[camels_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst,
                    state_vector_variables=['all']*n_particles)

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=50,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.943709176529834,0.2777103971835219,724.630336496298,3.640640141554399,0.21645064003429593,1.106'
#                     '796791505542,0.023927202255538862,0.0064308814919554055'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090519/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.7500553364444293,0.7679140522880052,566.6416122737787,3.5008654447825527,0.14846766000699754,3.'
#                     '645741090317686,0.02801713280043132,0.00927334670535975'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090520/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.264853624404938,0.6519409336346578,292.0884317238181,2.5964812918989337,0.2631882983772376,9.58'
#                     '7566595695623,0.04947048558314904,0.007503333425012307'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090522/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.945203688538553,0.860745591360004,375.73186382139505,1.4974819883264043,0.23572026943876126,6.4'
#                     '73576050805333,0.06526914776277042,0.006777518573585251'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090523/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.928514276932028,0.48218596864189306,736.4523240257254,2.122197008853905,0.1587897221200009,3.17'
#                     '18661126128045,0.01422560885771202,0.009152694978623305'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090525/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.2738265688235755,0.6693242565952258,418.83297591669316,2.2471673979127416,0.1779671832254088,9.'
#                     '97874144292236,0.015636001530932704,0.00395091804382267'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090526/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.1895271068447144,0.32036621326551606,382.46381888067873,1.6846358889632054,0.003469568362857496'
#                     '4,4.149488361873308,0.03248844926985797,0.000863517186951684'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090527/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.506590129493956,0.6928072504959406,307.7287636886969,2.5463991591122657,0.26268342276800416,9.9'
#                     '51747314316817,0.020138012171053946,0.00415838862918216'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090529/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.381670191601227,0.8892637240960328,484.35887894821633,2.0929725352668624,0.11544741188680001,3.'
#                     '489604933845822,0.06685510154406434,0.007841765956235031'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090530/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.014531645954227,0.8749276378898265,187.34370135198628,2.4347210776839368,0.09503618269148233,1.'
#                     '2596030077124991,0.09390075941020408,0.0053312733101301525'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090532/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.0916218912357607,0.9530614106106234,190.13547008527294,2.378821558601122,0.19461553479423385,8.'
#                     '686472242881603,0.04127590521626445,0.007852686464404113'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090533/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.8025305234839122,0.9390835017139232,660.8718018912955,2.682689944591582,0.22840764815130113,6.0'
#                     '386057017243555,0.07613121545126213,0.008396620109832503'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090534/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.2262480999391308,0.6796856575260486,603.9924194897728,2.4342487510939974,0.033999875449085684,8'
#                     '.31258745407591,0.08396209785616715,0.008903247553715238'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090536/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.076658597809272,0.9928319618878167,615.1245049613319,2.1772428675261057,0.1546657531056452,2.83'
#                     '917803728227,0.013246316201312267,0.008331171682852955'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090537/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.447583557400516,0.3593800174078487,117.2429750304355,2.5229946798852825,0.07196030200762443,9.5'
#                     '31817510167532,0.06108313778828371,0.006915299587409453'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090539/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.3683357381268326,0.8839077604367305,620.6124158233156,1.683485858689307,0.25137556061153427,8.9'
#                     '47172918323677,0.01684708927642986,0.008366978695334419'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090540/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.019112198317273,0.9585377811707796,458.85929273658945,0.6703397187032536,0.23711267459357083,4.'
#                     '6631409612941885,0.046236355104223574,0.008810473530875166'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090542/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.2554562031781673,0.9123521103826979,428.3563829994229,1.7361523806772932,0.09863045573814756,8.'
#                     '850881181528406,0.020900985114714228,0.008742492209219408'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090543/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.862990886163889,0.7422190881924404,427.1904019427813,3.5789112504131113,0.15339933900394304,9.9'
#                     '09352996947396,0.06692039224011176,0.0033578443926658105'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090545/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.563904817222996,0.635880206205873,645.6012290842895,2.94249270470602,0.1903300594746514,8.56512'
#                     '37390834,0.018431765586859016,0.00033351213466570713'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090546/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.5861567192593746,0.8547589923250094,787.9231093744277,3.628456541718987,0.09467469307951946,5.7'
#                     '50735567453294,0.040899778389561166,0.007026485210499801'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090547/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.5057443005417035,0.6329487257908615,485.6563264041125,2.229259201152621,0.022233515289959142,1.'
#                     '4007623842489427,0.04205874191449354,0.0017147657877148166'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090549/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.0593250599410515,0.6984011015671099,115.62754067179543,3.0849039084093053,0.15228580397325606,8'
#                     '.452962262936087,0.03041764486758232,0.0007039266961705807'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090550/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.553940297159163,0.4943174953946663,162.31427768348686,0.7641768778219435,0.07564417776254946,7.'
#                     '000667380089443,0.021307015749273323,0.003208780167709992'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090552/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
# ...
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.8062160794026516,0.221788004400311,118.77800043276373,2.856842951970606,0.15036400844980632,4.8'
#                     '40107118619561,0.030453717065633185,0.009999000687650432'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090619/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.339535217129721,0.7353022404681591,618.7039283579214,2.9749468038396136,0.13617134911961554,7.1'
#                     '26121983614561,0.030160023941932318,0.0035278021341321186'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090621/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.7901674661938385,0.8075348069035417,118.8560917771537,1.7767252928883843,0.021118591553056648,4'
#                     '.460510507131454,0.09867991092421237,0.006889339824014883'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090622/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.08040991344875,0.9025532018073525,715.1700959941281,3.2237924654491397,0.14664726331101074,4.16'
#                     '55487319951945,0.09496823096639874,0.0013323071326797739'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090624/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.909560008457476,0.9667831275361503,75.80729153597105,2.6737590719324045,0.0062980304687603635,6'
#                     '.449589520607497,0.06692312978817509,0.0012314042517476203'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090625/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.0173848539427208,0.7404160374228352,122.53236578283732,1.8677128143251278,0.2683224639661639,6.'
#                     '494734512469986,0.07396690450048839,0.0035973042595585035'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090627/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.1165893737014585,0.6422333603176866,574.946198442985,1.4917122341929976,0.1093055630815266,8.86'
#                     '6239023730895,0.032183612532477694,0.009250809936103553'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090628/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                 pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.570589110835046,0.8654882628771265,643.9672821157139,1.3990294264828391,0.14385698673441255,7.6'
#                     '2218987603449,0.043634451216091934,0.001755144042190734'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-25 10_06.nc',
#                     pev='HBV_forcing_test_2024-03-25 10_06.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_090629/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     prediction_variable_name=None,
#     observations=None,
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
# testing data 
ds_obs_dir = forcing_path / ref_model.forcing.pr
ds_obs = xr.load_dataset(ds_obs_dir)

# %%
# observations = observations_path / f'0{HRU_id}_streamflow_qc.txt'

# %%
# cubic_ft_to_cubic_m = 0.0283168466

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %%
# new_header = ['GAGEID','Year','Month', 'Day', 'Streamflow(cubic feet per second)','QC_flag']
# new_header_dict = dict(list(zip(range(len(new_header)),new_header)))

# df_Q = pd.read_fwf(observations,delimiter=' ',encoding='utf-8',header=None)
# df_Q = df_Q.rename(columns=new_header_dict)
# df_Q['Streamflow(cubic feet per second)'] = df_Q['Streamflow(cubic feet per second)'].apply(lambda x: np.nan if x==-999.00 else x)
# df_Q['Q (m3/s)'] = df_Q['Streamflow(cubic feet per second)'] * cubic_ft_to_cubic_m
# df_Q['Q'] = df_Q['Q (m3/s)'] / ds.attrs['area basin(m^2)'] * 3600 * 24 * 1000 # m3/s -> m/s ->m/d -> mm/d
# df_Q.index = df_Q.apply(lambda x: pd.Timestamp(f'{int(x.Year)}-{int(x.Month)}-{int(x.Day)}'),axis=1)
# df_Q.index.name = "time"
# df_Q.drop(columns=['Year','Month', 'Day','Streamflow(cubic feet per second)'],inplace=True)
# df_Q = df_Q.dropna(axis=0)

# ds_obs_dir = observations_path / f'0{HRU_id}_streamflow_qc.nc'
# ds_obs = xr.Dataset(data_vars=df_Q[['Q']])
# if not ds_obs_dir.exists():
#     ds_obs.to_netcdf(ds_obs_dir)

# %%
# ax = df_Q['Q'].plot()
# ax.set_xlim((pd.Timestamp(experiment_start_date),pd.Timestamp(experiment_end_date)))
# ax.set_ylabel("Q (mm/d)")
# ax.set_title("observations");

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
ensemble.initialize_method(ensemble_method_name = "EnKF", 
                           observation_path = ds_obs_dir,
                           observed_variable_name = "Q",
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.05,
                                               }
                            )

# %% [markdown]
# ## Run

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)
pbar = tqdm(total=n_timesteps)

time = []
lst_state_vector = []
lst_Q = [] 
while ref_model.time < ref_model.end_time:
    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update()
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q"))
    
    pbar.update(1)
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1126/1126 [39:32<00:00,  2.02s/it]

# %%
Q_m_arr = np.hstack(lst_Q)
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ## TODO: improve data handeling
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(glob.glob(str(output_path/'df_ensemble_*.feather'))[-1]) # read last

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])

# %% [markdown]
# # Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mean of 50 particles as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, ax = plt.subplots(1,1)

parameter="Tlag"
for i in range(n_particles):
    ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax)
ax.set_title(f'parameter={parameter} for {n_particles} Ensemble Members');

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)
