# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     2,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-10-01T00:00:00Z"
experiment_end_date = "1998-11-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle.forcing import sources

# %%
# camels_forcing = sources.HBVForcing(start_time = experiment_start_date,
#                           end_time = experiment_end_date,
#                           directory = forcing_path,
#                           camels_file = f'0{HRU_id}_lump_cida_forcing_leap.txt',
#                           alpha = alpha
#                           )

# %% [markdown]
# adjust caravan for syntax

# %%
camels_forcing = sources.HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          pr = f'camels_01022500.nc',
                          pev = f'camels_01022500.nc', 
                          )

# %%
# ds = xr.open_dataset(forcing_path / 'camels_01022500.nc')
# ds = ds.rename_dims({'date': 'time'})
# ds = ds.rename({'date': 'time'})

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 10

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=10,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     prediction_variable_name=None,
#     observations=None,
#     lst_models_name=[],
#     logger=[],
# )

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[camels_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst,
                    state_vector_variables=['all']*n_particles)

# %% [markdown]
# Need to add `'pev'` and `'pr'`

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
# ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
# testing data 
ref_model = ensemble.ensemble_list[0].model
ds_obs_dir = forcing_path / ref_model.forcing.pr
ds_obs = xr.load_dataset(ds_obs_dir)

# %%
# observations = observations_path / f'0{HRU_id}_streamflow_qc.txt'

# %%
# cubic_ft_to_cubic_m = 0.0283168466

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %%
# new_header = ['GAGEID','Year','Month', 'Day', 'Streamflow(cubic feet per second)','QC_flag']
# new_header_dict = dict(list(zip(range(len(new_header)),new_header)))

# df_Q = pd.read_fwf(observations,delimiter=' ',encoding='utf-8',header=None)
# df_Q = df_Q.rename(columns=new_header_dict)
# df_Q['Streamflow(cubic feet per second)'] = df_Q['Streamflow(cubic feet per second)'].apply(lambda x: np.nan if x==-999.00 else x)
# df_Q['Q (m3/s)'] = df_Q['Streamflow(cubic feet per second)'] * cubic_ft_to_cubic_m
# df_Q['Q'] = df_Q['Q (m3/s)'] / ds.attrs['area basin(m^2)'] * 3600 * 24 * 1000 # m3/s -> m/s ->m/d -> mm/d
# df_Q.index = df_Q.apply(lambda x: pd.Timestamp(f'{int(x.Year)}-{int(x.Month)}-{int(x.Day)}'),axis=1)
# df_Q.index.name = "time"
# df_Q.drop(columns=['Year','Month', 'Day','Streamflow(cubic feet per second)'],inplace=True)
# df_Q = df_Q.dropna(axis=0)

# ds_obs_dir = observations_path / f'0{HRU_id}_streamflow_qc.nc'
# ds_obs = xr.Dataset(data_vars=df_Q[['Q']])
# if not ds_obs_dir.exists():
#     ds_obs.to_netcdf(ds_obs_dir)

# %%
# ax = df_Q['Q'].plot()
# ax.set_xlim((pd.Timestamp(experiment_start_date),pd.Timestamp(experiment_end_date)))
# ax.set_ylabel("Q (mm/d)")
# ax.set_title("observations");

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
ensemble.initialize_method(ensemble_method_name = "PF", 
                           observation_path = ds_obs_dir,
                           observed_variable_name = "Q",
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.005,
                                               }
                            )

# %% [markdown]
# ## Run

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=10,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.577019094751063,0.9871599030056208,101.07028530390912,1.5119886720145315,0.2779428008404854,1.0'
#                     '945686077780161,0.037906677643398334,0.0007146636429094374'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142426/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.459553434922843,0.5933539269967851,244.03318427493085,2.589967109062928,0.2169486456629766,1.69'
#                     '00092227881505,0.06242674709793085,0.004497499299548141'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142427/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.5156527145946592,0.9347677434505985,68.7305246574119,2.7474269741202644,0.2386502917480524,1.16'
#                     '59089444158623,0.06992221297056905,0.007186320977879546'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142429/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.7813501653057324,0.4967562839954683,651.5768540702645,2.116768756690421,0.0709772058892093,1.20'
#                     '79258314298287,0.03430399185079131,0.0005725028417169646'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142430/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.437003402907974,0.3831469878378094,727.1605517456401,3.0823983750330664,0.0575014956293765,1.95'
#                     '21988674509823,0.08473546928921545,0.007125863281461319'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142431/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.859667563139786,0.9796315920288059,510.4391721129985,3.041382169543287,0.02026475640506219,1.06'
#                     '55472425884986,0.07831583919031133,0.006257488784902359'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142433/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.513146914012029,0.9800704833044529,798.7901667909628,2.4336173771579706,0.0322905940560867,1.34'
#                     '85025207837373,0.09447544010918661,0.008459304055821496'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142434/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.976523878104702,0.29610754636798187,433.117766392577,3.2724719501407353,0.004347843366832336,1.'
#                     '4695270686694137,0.09544902407091684,0.0067675254674904785'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142436/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.3754997113843981,0.9231305070957465,446.8702506424194,3.1799171162725663,0.1133868746651495,1.5'
#                     '519957884797497,0.08414293235265577,0.0006304659898782777'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142437/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='.txt',
#                 pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                 pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.6452471009400789,0.5074089307389593,415.9606920786846,2.060700431245374,0.0585860738107654,1.65'
#                     '45985556502294,0.014134571825140125,0.0065134011905165785'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='.txt',
#                     pr='HBV_forcing_external_2024-03-21 15_24.nc',
#                     pev='HBV_forcing_external_2024-03-21 15_24.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240321_142439/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#     ],
#     ensemble_method=ParticleFilter(
#         hyperparameters={
#             'like_sigma_weights': 0.05,
#             'like_sigma_state_vector': 0.005,
#         },
#         N=10,
#         obs=None,
#         state_vectors=None,
#         predictions=None,
#         weights=None,
#         resample_indices=None,
#         new_state_vectors=None,
#     ),
#     ensemble_method_name='PF',
#     observed_variable_name='Q',
#     prediction_variable_name='Q',
#     observations=(
#         <xarray.DataArray 'Q' (time: 397)>
#         [397 values with dtype=float32]
#         Coordinates:
#           * time     (time) datetime64[ns] 1997-10-01 1997-10-02 ... 1998-11-01
#     ),
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)

time = []
lst_state_vector = []
lst_Q = [] 
for _ in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update()
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q").flatten())
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 396/396 [02:38<00:00,  2.50it/s]

# %% [markdown]
# run 13/03 11:34, 3 years, 30 particles = 27min note: runnning two at once <br>
# run 13/03 11:46, 1 year, 1 particle = 1 min <br>
# run 13/03 12:01, 1 year, 35 particles = 10min <br>
# run 13/03 13:13, 1 year, 100 particles = 31min <br>
# run 13/03 14:30, 1 year, 100 particles = 25min (EnKF) <br>
# run 13/03 14:45, 1 year, 200 particles = 1hr?min  <br>

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = True, False
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(glob.glob(str(output_path/'df_ensemble_*.feather'))[-1]) # read last

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])

# %% [markdown]
# ## Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
# ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mea as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)
