# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

from cartopy.io import shapereader

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# pip uninstall ewatercycle-hbv -y

# %%
# pip install git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"

shapeFile = forcing_path/ "Rhine_shp" / "Rhine.shp"

#location to saved forcing results from previous notebook
forcingLocation = forcing_path / "RhineForcing2000-2002"

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     2,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
#period of interest. Make sure that GRDC data is available for this period and that.
experiment_start_time="2000-01-01T00:00:00Z"
experiment_end_time="2002-12-31T00:00:00Z"

#GRDC station ID for the observation station
grdc_station_id = "6335020"  # GRDC station ID
basin_name = "Rhine"
observation_path = path / "Observations"

# %%
from ewatercycle.forcing import sources

# %%
ERA5_forcing = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(forcingLocation)

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %%
import ewatercycle_HBV

# %%
ewatercycle_HBV.__version__
# Out:
# '1.6.1'

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
# DA = module_from_file("DA",r'../eWaterCycle-DA/src/ewatercycle_DA/DA.py')

# %%
from ewatercycle_DA import DA

# %%
n_particles = 30

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
# pprint(ensemble)

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
ERA5_forcing
# Out:
# LumpedMakkinkForcing(start_time='2000-01-01T00:00:00Z', end_time='2002-12-31T00:00:00Z', directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'), shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'), filenames={'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc', 'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc', 'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc', 'evspsblpot': 'Derived_Makkink_evspsblpot.nc'})

# %%
ds = xr.open_dataset(ERA5_forcing.directory /ERA5_forcing.filenames['pr'])
attributes = ds['pr'].attrs
attributes['units'] = 'mm'
ds['pr'] = ds['pr'] * 86400
ds['pr'].attrs = attributes
# ds.to_netcdf(temporary_pr_file)
# ds.close()

# %%
# this initializes the models for all ensemble members. 
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[ERA5_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst)

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if initialize fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
# ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
# testing data 
ref_model = ensemble.ensemble_list[0].model
ds_obs_dir_pd = observation_path / f'{grdc_station_id}_Q_Day.feather'
ds_obs_pd = pd.read_feather(ds_obs_dir_pd)
ds_obs_pd = ds_obs_pd.rename(columns={"streamflow":"Q"})

# %% [markdown]
# streamflow in m3/s to mm/d:

# %%
shapeObject = shapereader.Reader(shapeFile.absolute())
record = next(shapeObject.records())
shape_area = record.attributes["SUB_AREA"] * 1e6

# %%
ds_obs_pd['Q'] = ds_obs_pd['Q'] / shape_area * (1000 * 86400)

# %%
ds_obs = xr.Dataset(ds_obs_pd)
ds_obs_dir = observation_path / f'{grdc_station_id}_Q_mm_Day.nc'
ds_obs.to_netcdf(ds_obs_dir)

# %%
plt.plot(ds_obs_pd)

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
def H(Z):
    if len(Z) == 13:
        return Z[-1] 
    else: 
        raise SyntaxWarning(f"Length of statevector should be 13 but is {len(Z)}")

# %%
ensemble.initialize_da_method(ensemble_method_name = "PF", 
                              hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.005,
                                                 },
                              
                              state_vector_variables = "all", # the next three are keyword arguments but are needed. 
                              observation_path = ds_obs_dir,
                              observed_variable_name = "Q",
                              measurement_operator = H, 
                           
                            )

# %% [markdown]
# ## Run

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.5392114843799876,0.3530117479384924,58.75944361487729,1.771378666804707,0.28419372581557595,1.4'
#                     '29881004289481,0.08524463882851988,0.0021696340538104684'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171807/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.268910057460877,0.4803670001012892,768.4271387074148,1.8574969686195888,0.14077077911440952,1.6'
#                     '409520844877592,0.07703887157665613,0.006723747004156288'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171808/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.396898153979891,0.9095255423324977,757.7992252768623,1.8389275674598609,0.030544592992200432,1.'
#                     '3530614046403633,0.04875658265057472,0.0013786789460335342'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171809/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.4616905020703816,0.6995963502363682,617.2421539649627,3.7539326533179405,0.08306616067335287,1.'
#                     '8274316810939961,0.06436262981059464,0.009465775129468224'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171811/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.051447774546214,0.8179334859333811,714.0789731419667,3.286470912948007,0.2720014837870442,1.736'
#                     '946338541804,0.08561820615400738,0.006773021192210627'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171812/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.2048512391578745,0.2246594267911209,144.81011834876847,1.0998503134016968,0.057486778481820926,'
#                     '1.7300523086139603,0.07228082705394737,0.007894467477146352'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171814/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.9252773396520739,0.8428697582730789,398.11070153834555,2.67174965066002,0.2062127685056428,1.22'
#                     '9986321518936,0.09110849971095025,0.00554985322487584'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171815/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.352142885932646,0.3841052726568629,743.0704160652207,0.9228443148877206,0.29354729918726474,1.6'
#                     '912071903404353,0.05677921750419859,0.004729654340988489'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171817/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.9783162277358421,0.2342431448566954,143.69679304691414,3.104862802096808,0.07522439651573498,1.'
#                     '1342199303699876,0.06264519931176686,0.008422827166447606'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171818/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.9262780188324964,0.6594761675189107,45.6910462454431,2.0520431533595103,0.0022002899797171627,1'
#                     '.2881383140640994,0.046833063747416456,0.004370156990185606'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171819/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.9572062424851806,0.5679634760709671,124.98739467876267,3.02966422426537,0.09924608140200264,1.0'
#                     '257929319182155,0.01826898446936369,0.002086481379364198'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171821/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.274561496121975,0.8211218200290016,745.6446405652138,2.935007370834422,0.20331472150800817,1.82'
#                     '15947126646943,0.02786126601782747,0.005614528570060957'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171822/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.68626798900215,0.8911844110566081,326.4439583589168,2.7023931895891455,0.14036753705029764,1.43'
#                     '59805011109033,0.07093279954352767,0.0010870045845948145'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171824/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.112525647831362,0.4538556452659355,274.42540967217565,1.0575357271854706,0.273117638432068,1.45'
#                     '93122933270117,0.026967729225490226,0.005575211392443703'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171825/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.167284815388223,0.86235493529689,657.6234502434345,2.253753270864154,0.171460405759561,1.158254'
#                     '6401576543,0.07765241004056747,0.004561853534876607'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171826/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.8560740387989165,0.7968012550833838,384.9381543320804,3.793914877283063,0.2739507993953842,1.82'
#                     '01556846383675,0.07243186282872928,0.0036564823894994995'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171828/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.330013265859284,0.3995402615596998,273.6519001809281,1.7739241645778383,0.14122714542186673,1.0'
#                     '459452857844052,0.08614971617951811,0.007879257125098413'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171829/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.44188402097116,0.3268378375240891,595.2149508036371,2.7445122353390006,0.20098558229762672,1.63'
#                     '97577995332688,0.01761312452810508,0.005418522135697186'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171831/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.520625658401154,0.7966826979536723,774.1546247147027,3.277870299056891,0.12071577654078633,1.00'
#                     '4297314712487,0.039584730070039174,0.003338116163265563'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171832/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.3601989548411684,0.5575528495403012,751.4182070022242,2.0921159647819896,0.016848947706714894,1'
#                     '.247756022839964,0.0795061334272236,0.001654228439584091'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
# ...
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171839/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.8963052975287136,0.7885100175443365,67.97756449972505,3.216100792496751,0.23083333364648126,1.8'
#                     '350257213095609,0.05826333213081797,0.0015379269823932752'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171840/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.358474350615602,0.6967757697856074,321.2964447663411,0.7989719935417657,0.27856031077051074,1.9'
#                     '92660746476025,0.019273045726436976,0.00978838009473022'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171842/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.7655261700435281,0.8397430237091381,301.63533230216103,0.6604207500862612,0.26462833021055676,1'
#                     '.1492676828456703,0.0721041628886087,0.007475220441842066'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171843/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.0183826051686324,0.29632573517542593,288.8149409998075,2.538175329889586,0.217257189717641,1.64'
#                     '0411541691206,0.09704353553481951,0.005438636754583953'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171845/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.7656107794093066,0.7735534959718102,283.40319207794323,2.8259434895483873,0.10988997950689476,1'
#                     '.960814855174017,0.07753119098404158,0.00022365617561757032'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171846/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=LumpedMakkinkForcing(
#                 start_time='2000-01-01T00:00:00Z',
#                 end_time='2002-12-31T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                 shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                 filenames={
#                     'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                     'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                     'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                     'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                 },
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.037181408740956,0.2177937257157864,687.8438289595057,1.7003323400479415,0.2612278620274462,1.34'
#                     '18495209717207,0.0394027749416739,0.004110247170770137'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=LumpedMakkinkForcing(
#                     start_time='2000-01-01T00:00:00Z',
#                     end_time='2002-12-31T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002'),
#                     shape=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing/RhineForcing2000-2002/Rhine.shp'),
#                     filenames={
#                         'pr': 'OBS6_ERA5_reanaly_1_day_pr_2000-2002.nc',
#                         'tas': 'OBS6_ERA5_reanaly_1_day_tas_2000-2002.nc',
#                         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_2000-2002.nc',
#                         'evspsblpot': 'Derived_Makkink_evspsblpot.nc',
#                     },
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240329_171847/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#     ],
#     ensemble_method=ParticleFilter(
#         hyperparameters={
#             'like_sigma_weights': 0.05,
#             'like_sigma_state_vector': 0.005,
#         },
#         N=30,
#         obs=None,
#         state_vectors=None,
#         predictions=None,
#         weights=None,
#         resample_indices=None,
#         new_state_vectors=None,
#     ),
#     ensemble_method_name='PF',
#     observed_variable_name='Q',
#     measurement_operator=<function H at 0x7f70e41488b0>,
#     observations=(
#         <xarray.DataArray 'Q' (time: 1096)>
#         [1096 values with dtype=float64]
#         Coordinates:
#           * time     (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2002-12-31
#     ),
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)

time = []
lst_state_vector = []
lst_Q = [] 
for _ in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update(assimilate=True)
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q").flatten())
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1095/1095 [22:58<00:00,  1.26s/it]

# %%
# ensemble.finalize()

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False 
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(sorted(glob.glob(str(output_path/'df_ensemble_*.feather')))[-1]) # read last
    time = list(df_ensemble.index)

# %%
df_ensemble.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-12-21', '2002-12-22', '2002-12-23', '2002-12-24',
#                '2002-12-25', '2002-12-26', '2002-12-27', '2002-12-28',
#                '2002-12-29', '2002-12-30'],
#               dtype='datetime64[ns]', length=1095, freq=None)

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])
    time = ds_combined.time.values
    n_particles = len(ds_combined.EnsembleMember)

# %% [markdown]
# ## Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
# ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mea as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"NSe mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
param_names_0 = param_names[:4]
param_names_1 = param_names[4:]

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_0):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
# [ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_1):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
# [ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)
