# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
from pydantic import BaseModel
from typing import Any

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     2,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-08-01T00:00:00Z"
experiment_end_date = "2000-09-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle.forcing import sources

# %%
sources.LorenzForcing
# Out:
# ewatercycle_lorenz.forcing.LorenzForcing

# %%
test_forcing = sources.HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'test_forcing.txt',
                          test_data_bool = True 
                          )

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 30

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables=None,
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     measurement_operator=None,
#     observations=None,
#     lst_models_name=[],
#     logger=[],
# )

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
# this initializes the models for all ensemble members. 
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[test_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst)

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
# ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
# testing data 
ref_model = ensemble.ensemble_list[0].model
ds_obs_dir = forcing_path / ref_model.forcing.pr
ds_obs = xr.load_dataset(ds_obs_dir)

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
def H(Z):
    if len(Z) == 13:
        return Z[-1] 
    else: 
        raise SyntaxWarning(f"Length of statevector should be 9 but is {len(Z)}")

# %%
ensemble.initialize_da_method(ensemble_method_name = "PF", 
                              hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.005,
                                                 },
                              
                              state_vector_variables = "all", # the next three are keyword arguments but are needed. 
                              observation_path = ds_obs_dir,
                              observed_variable_name = "Q",
                              measurement_operator = H, 
                           
                            )

# %% [markdown]
# ## Run

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.5676260918243115,0.2709995520384082,106.92049796559628,2.828526021058484,0.09826398651161398,1.'
#                     '5853728154403994,0.08488797073605332,0.004824056487229314'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105832/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.8099574749806973,0.9513722599856067,325.5104946096703,3.83371644651124,0.014476275650362712,1.4'
#                     '634463922001912,0.03888352182756122,0.006896303733971158'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105834/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.46518614048454,0.6500261434455998,237.15931519354788,2.792627229707906,0.20569838204537724,1.87'
#                     '63345800321054,0.0343377300525935,0.005003486312476822'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105835/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.979418756146834,0.7803191887439951,443.91361193448887,1.7798279965491617,0.11691827857144312,1.'
#                     '557162675089871,0.09248566699403964,0.0019111599508749037'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105836/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.3905920525564115,0.6329270107000765,786.209716775581,1.3499240437141382,0.11769581902290614,1.8'
#                     '500671289779231,0.04607345609100342,0.0024962529154361375'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105838/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.767953169534027,0.27070743755815274,311.1298513329348,3.9476165220565598,0.26065477852070906,1.'
#                     '5162855997192493,0.023823924019115983,0.004958261328769942'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105839/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.044631624880394405,0.9304674205629131,328.1771278485244,1.7444507923563042,0.16969917486276997,'
#                     '1.0170805382733223,0.05315805589238121,0.005595728800485381'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105841/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.6651812376714838,0.6623620444544167,179.1531248274913,2.2763071995634157,0.2150173232642247,1.7'
#                     '217898402756333,0.05079784746122393,0.0012775341088165852'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105842/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.780768544520085,0.6213421327409092,43.262233426945095,2.4011805398712536,0.29193655055708445,1.'
#                     '5725804600355833,0.017698520733976073,0.0036346853247700745'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105844/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.592433871631324,0.43227646720012614,780.218446414659,1.6515630194637192,0.003806728800794843,1.'
#                     '8120634341446067,0.05226770541980578,0.007646498376298839'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105845/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.574573470317256,0.7795831254651884,526.0652812229982,1.9621246562006645,0.29174997735608305,1.2'
#                     '77192180590315,0.09034498064912785,0.004766215288412956'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105847/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.023078318711649892,0.5429738531218546,676.2046284154037,1.552990527556673,0.1617170018447356,1.'
#                     '4438516600325682,0.07006053893992105,0.007336151894183945'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105848/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.6053069407508609,0.4834796239639414,493.50162433656317,1.396062089734737,0.1465294198378198,1.4'
#                     '76144061431949,0.08856123704252572,0.002844474540226979'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105850/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.607938239275586,0.6864066556675469,167.11823631143287,3.074670037368863,0.2379743252332529,1.79'
#                     '59067466673209,0.046074474012186846,0.003869888625489177'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105851/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.457963331606104,0.2697896811131272,178.51665769130614,0.7930944572707821,0.13754517528629953,1.'
#                     '1273415082581637,0.02088653195467212,0.0024255539021816766'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105853/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.335189185932938,0.20200450657239044,48.33430162983773,0.6442053226935154,0.20252816843796193,1.'
#                     '3230015627250074,0.07954714335866639,0.006909683744763285'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105854/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.7670802837138337,0.6340367481574909,460.79441137682056,2.6314855245893636,0.0491742574060899,1.'
#                     '4417505604765666,0.03436392816805893,0.0016603918505231528'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105856/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.1326703326648948,0.8297056534579355,265.01273582431736,2.5591143322317866,0.2088425843738946,1.'
#                     '8295749867367492,0.048584593359298676,0.004902626860892677'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105857/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.706744534530512,0.809060777105155,729.484685950961,3.8918555814060225,0.06301488765249016,1.078'
#                     '0827848736707,0.04564662737995622,0.005608478847526146'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105858/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.7073547381433816,0.9671886479605674,488.47243235385355,0.7092912574089449,0.21599668622362034,1'
#                     '.0737003841438082,0.04725890668319238,0.006955863904939932'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105900/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.5438694237785109,0.8421251178426585,791.180977489964,0.6226136397650193,0.08181460834850925,1.9'
#                     '508233583854118,0.08969510472086777,0.008686174620335184'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105901/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.252564511754662,0.7091746292266323,341.1232900217163,1.3578112851920827,0.14420887871503388,1.4'
#                     '950947663683982,0.06256621581524319,0.006031449963753172'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105903/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.2845599868766095,0.8515273109294494,68.36131521574339,1.3767709596120705,0.11664233113818212,1.'
#                     '2739331432014902,0.044065013907547065,0.0033813284168638063'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105904/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.438562214637618,0.9926795090208298,355.4255602883091,1.1905217977324192,0.0397308190074599,1.96'
#                     '47315509350547,0.07348965746791633,0.0041959091196489134'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105906/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.613200516469,0.36613928241104043,42.459583960448356,3.816146287068949,0.29335702047030043,1.967'
#                     '04180328365,0.04287844905242595,0.0057661537828312456'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105907/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.749471334493685,0.27309220422130054,583.5268012869943,1.5885831161886546,0.13711621513460678,1.'
#                     '6835422060961207,0.014862165774799724,0.002122328248687216'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105909/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.5101061805687905,0.2979223114627028,394.3733198720552,3.9303398541252985,0.09458910242023509,1.'
#                     '3381981512632524,0.018551929754536116,0.0037991987477319013'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105910/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.5673991908735685,0.9796594478907916,549.6473256500763,2.4083225245493347,0.13285841861767198,1.'
#                     '1985948549297063,0.059990972945606624,0.006287477771123471'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105911/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.842920191302348,0.7374606667532186,413.2272909941392,2.115316158282928,0.09137218642592984,1.15'
#                     '4434963818669,0.08041369153117628,0.002822144464894685'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105913/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2000-09-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                 pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.05498314982109,0.5838633199643748,435.8733452647941,2.8242623234410043,0.27038653263647444,1.77'
#                     '69918195728063,0.08813886513736441,0.007772906932872979'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2000-09-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_test_2024-03-26 11_59.nc',
#                     pev='HBV_forcing_test_2024-03-26 11_59.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240326_105914/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#                 'Q',
#             ],
#         ),
#     ],
#     ensemble_method=ParticleFilter(
#         hyperparameters={
#             'like_sigma_weights': 0.05,
#             'like_sigma_state_vector': 0.005,
#         },
#         N=30,
#         obs=None,
#         state_vectors=None,
#         predictions=None,
#         weights=None,
#         resample_indices=None,
#         new_state_vectors=None,
#     ),
#     ensemble_method_name='PF',
#     observed_variable_name='Q',
#     measurement_operator=<function H at 0x7f9d30666290>,
#     observations=(
#         <xarray.DataArray 'Q' (time: 1127)>
#         [1127 values with dtype=float64]
#         Coordinates:
#           * time     (time) datetime64[ns] 1997-08-01 1997-08-02 ... 2000-08-31
#     ),
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)

time = []
lst_state_vector = []
lst_Q = [] 
for _ in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update(assimilate=True)
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q").flatten())
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1126/1126 [24:38<00:00,  1.31s/it]

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False 
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(sorted(glob.glob(str(output_path/'df_ensemble_*.feather')))[-1]) # read last
    time = list(df_ensemble.index)

# %%
df_ensemble.index
# Out:
# DatetimeIndex(['1997-08-01', '1997-08-02', '1997-08-03', '1997-08-04',
#                '1997-08-05', '1997-08-06', '1997-08-07', '1997-08-08',
#                '1997-08-09', '1997-08-10',
#                ...
#                '2000-08-21', '2000-08-22', '2000-08-23', '2000-08-24',
#                '2000-08-25', '2000-08-26', '2000-08-27', '2000-08-28',
#                '2000-08-29', '2000-08-30'],
#               dtype='datetime64[ns]', length=1126, freq=None)

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])
    time = ds_combined.time.values
    n_particles = len(ds_combined.EnsembleMember)

# %% [markdown]
# ## Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
# ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mea as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"NSe mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
param_names_0 = param_names[:4]
param_names_1 = param_names[4:]

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_0):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
# [ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_1):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
# [ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)
