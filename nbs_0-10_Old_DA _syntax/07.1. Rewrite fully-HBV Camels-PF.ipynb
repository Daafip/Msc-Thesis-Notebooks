# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint
from tqdm import tqdm

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     2,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-08-01T00:00:00Z"
experiment_end_date = "2005-10-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle.forcing import sources

# %%
camels_forcing = sources.HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'0{HRU_id}_lump_cida_forcing_leap.txt',
                          alpha = alpha
                          )

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 30

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     prediction_variable_name=None,
#     observations=None,
#     lst_models_name=[],
#     logger=[],
# )

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[camels_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst,
                    state_vector_variables=['all']*n_particles)

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
observations = observations_path / f'0{HRU_id}_streamflow_qc.txt'

# %%
cubic_ft_to_cubic_m = 0.0283168466

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %%
new_header = ['GAGEID','Year','Month', 'Day', 'Streamflow(cubic feet per second)','QC_flag']
new_header_dict = dict(list(zip(range(len(new_header)),new_header)))

df_Q = pd.read_fwf(observations,delimiter=' ',encoding='utf-8',header=None)
df_Q = df_Q.rename(columns=new_header_dict)
df_Q['Streamflow(cubic feet per second)'] = df_Q['Streamflow(cubic feet per second)'].apply(lambda x: np.nan if x==-999.00 else x)
df_Q['Q (m3/s)'] = df_Q['Streamflow(cubic feet per second)'] * cubic_ft_to_cubic_m
df_Q['Q'] = df_Q['Q (m3/s)'] / ds.attrs['area basin(m^2)'] * 3600 * 24 * 1000 # m3/s -> m/s ->m/d -> mm/d
df_Q.index = df_Q.apply(lambda x: pd.Timestamp(f'{int(x.Year)}-{int(x.Month)}-{int(x.Day)}'),axis=1)
df_Q.index.name = "time"
df_Q.drop(columns=['Year','Month', 'Day','Streamflow(cubic feet per second)'],inplace=True)
df_Q = df_Q.dropna(axis=0)

ds_obs_dir = observations_path / f'0{HRU_id}_streamflow_qc.nc'
ds_obs = xr.Dataset(data_vars=df_Q[['Q']])
if not ds_obs_dir.exists():
    ds_obs.to_netcdf(ds_obs_dir)

# %%
ax = df_Q['Q'].plot()
ax.set_xlim((pd.Timestamp(experiment_start_date),pd.Timestamp(experiment_end_date)))
ax.set_ylabel("Q (mm/d)")
ax.set_title("observations");

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
ensemble.initialize_method(ensemble_method_name = "PF", 
                           observation_path = ds_obs_dir,
                           observed_variable_name = "Q",
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.01,
                                               }
                            )

# %% [markdown]
# ## Run

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.405661164304128,0.9703730933511723,450.865865871785,3.064993086059704,0.22642758153808554,1.297'
#                     '3930359842942,0.024896197684968473,0.0036182351958493415'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133544/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.9481915815454238,0.21894657190206157,753.2893391509843,0.6326802856598541,0.24670004850191576,1'
#                     '.2516109412729337,0.0783239510887317,0.00034814958948097344'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133545/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.9246858697396458,0.33147006314737837,406.7552823231892,1.6851468585918683,0.2958853417699266,1.'
#                     '3464722648114118,0.08135129542623404,0.004054841969670567'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133547/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.948039676693153,0.749675758950237,739.0790180853026,3.3475063354858112,0.17054943206919246,1.10'
#                     '73949076168397,0.05476314823464809,0.0004974009786183784'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133549/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.18193059437578896,0.6376151261807126,69.11421717345391,3.6796300602722467,0.27495270275701594,1'
#                     '.465029119567062,0.030444676903102035,0.007676670135111826'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133551/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.126921957802689,0.3421372818482433,191.53572154475305,3.4421491142995007,0.12163548069570222,1.'
#                     '0267224290722425,0.03685880175045908,0.0009050076310634295'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133553/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.418484583335195,0.7592382195472276,609.2902674981673,2.217456303881843,0.04391435251799961,1.38'
#                     '35723479602116,0.062452783217775934,0.008244954946801941'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133554/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.151702535312549,0.38075263028835277,71.36757398980576,3.7941878237598434,0.10794129721424249,1.'
#                     '4260278175978789,0.029936919092517715,0.0031505272956724754'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133556/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.772328935323509,0.5734350997657249,497.4787219190165,3.486364455672856,0.03903501028922518,1.68'
#                     '73255497393045,0.01181549217915744,0.006866871415262747'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133558/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.469023197199307,0.9409587877997163,795.9807454278013,1.5286747681620487,0.25559450484899376,1.3'
#                     '973131173218842,0.02793802570833047,0.0013746260641582493'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133559/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.7272129340407405,0.41359922089050305,109.89833966865525,1.7199266469843764,0.20629710244486005,'
#                     '1.5837232082541883,0.03769846091997173,0.007828202024579447'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133601/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.527024126932683,0.9369378360523091,399.9151801730839,2.2930961071672273,0.2545452535424686,1.62'
#                     '74957579152005,0.0979372971523155,0.005637281588386383'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133603/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.7672065275649729,0.9325827369626416,82.24990163071602,1.1248684776580733,0.027428373342895607,1'
#                     '.1734931126226702,0.057077624460222874,0.0032511311815737643'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133605/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.4654448537954625,0.6771410068022927,196.28260967382084,2.149545617986796,0.282508986964772,1.67'
#                     '40198037086742,0.012451490382286177,0.0013739121816926162'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133606/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.635090170380379,0.8277764948241892,457.59456866191493,3.1089302909834378,0.20238199748687757,1.'
#                     '9315693201913247,0.06935126582540498,0.007157130491999656'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133608/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.0518063639576685,0.5069951163261073,265.02250166863246,0.7801316363235633,0.006052671196998134,'
#                     '1.0929985344511821,0.04320258524816922,0.004395004784538118'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133610/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.165866590104442,0.322730508658962,277.44856978588535,2.596749701681178,0.0588586095301835,1.414'
#                     '5927923209172,0.043284567965543676,0.0011649899753323565'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133612/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.5262699725807627,0.382407058106711,81.79431119633946,2.320067860476067,0.10484697294043023,1.65'
#                     '01214897484775,0.03660382091860732,0.006167511752311546'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133613/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.486216756525562,0.916624425024575,156.54852198469652,2.712054347913715,0.10411248763536414,1.76'
#                     '5331251135573,0.010331908266885343,0.0023562278917799964'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133615/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.883678805629447,0.4298560438649133,359.09248189666243,0.8435743345135431,0.02301056641263285,1.'
#                     '4647506258134384,0.06477332021563953,0.0029753855699249793'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133617/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.672008226596247,0.5606699882580493,367.50978095220574,3.54826522384511,0.03947994741027394,1.60'
#                     '57481131810278,0.05518770912812065,0.0002906217769044406'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133619/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.246790871474678,0.8732343683248092,111.22008531447364,2.983517782222568,0.15210962865318717,1.8'
#                     '91200824798216,0.024878217244703276,0.0006831719927219268'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133621/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.9237465185512832,0.24615328264674244,543.783809543374,0.7122500493308576,0.11192813766110234,1.'
#                     '8442818326642034,0.03426035831676843,0.0004612242621186137'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133622/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.8513176057540024,0.9796241501153049,774.7529417495227,2.436697420577987,0.1717486625063085,1.67'
#                     '8664366993727,0.02783376735810794,0.008438978131109897'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133624/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.49556216408206,0.8609724777031427,576.1259828163451,2.6424625420040226,0.24457485356294711,1.77'
#                     '5810159375773,0.032996209628300605,0.007138782301385529'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133626/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.16417581085658828,0.5271271339700139,365.69906974811704,1.5097115837233444,0.29809279348327244,'
#                     '1.711097851220169,0.0661768176883103,0.0014934911561973211'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133627/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.212711422478748,0.8290990577082804,286.9541071255816,3.2322648173547446,0.10529957941289673,1.2'
#                     '722787736443517,0.019344919541890087,0.0007674656051543552'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133629/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.8567039591027408,0.37564944461863564,778.4673889355989,3.191449776222873,0.09378420830195464,1.'
#                     '0967110660206587,0.07670002220080005,0.006500283680783221'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133631/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.402759521529336,0.5177647635077887,748.8470027426988,0.8961195292627759,0.24641974675783807,1.7'
#                     '241333836125485,0.09198243998841607,0.003974019305792455'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133633/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-08-01T00:00:00Z',
#                 end_time='2005-10-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '5.102493447458502,0.5292002095323187,388.411856821702,3.384804473503155,0.25408674950781324,1.009'
#                     '733860953772,0.01678596387036662,0.0039701814186972354'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-08-01T00:00:00Z',
#                     end_time='2005-10-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-25 14_36.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240325_133635/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#     ],
#     ensemble_method=ParticleFilter(
#         hyperparameters={
#             'like_sigma_weights': 0.05,
#             'like_sigma_state_vector': 0.01,
#         },
#         N=30,
#         obs=None,
#         state_vectors=None,
#         predictions=None,
#         weights=None,
#         resample_indices=None,
#         new_state_vectors=None,
#     ),
#     ensemble_method_name='PF',
#     observed_variable_name='Q',
#     prediction_variable_name='Q',
#     observations=(
#         <xarray.DataArray 'Q' (time: 12784)>
#         [12784 values with dtype=float64]
#         Coordinates:
#           * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-12-31
#     ),
#     lst_models_name=['HBV'],
#     logger=[],
# )

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)

time = []
lst_state_vector = []
lst_Q = [] 
for _ in tqdm(range(n_timesteps)):    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update()
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q").flatten())
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2983/2983 [1:09:54<00:00,  1.41s/it]

# %% [markdown]
# run 13/03 11:34, 3 years, 30 particles = 27min note: runnning two at once <br>
# run 13/03 11:46, 1 year, 1 particle = 1 min <br>
# run 13/03 12:01, 1 year, 35 particles = 10min <br>
# run 13/03 13:13, 1 year, 100 particles = 31min <br>
# run 13/03 14:30, 1 year, 100 particles = 25min (EnKF) <br>
# run 13/03 14:45, 1 year, 200 particles = 1hr?min  <br>

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False 
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(sorted(glob.glob(str(output_path/'df_ensemble_*.feather')))[-1]) # read last
    # time = list(df_ensemble.index)

# %%
df_ensemble.index
# Out:
# DatetimeIndex(['1997-08-01', '1997-08-02', '1997-08-03', '1997-08-04',
#                '1997-08-05', '1997-08-06', '1997-08-07', '1997-08-08',
#                '1997-08-09', '1997-08-10',
#                ...
#                '2005-09-21', '2005-09-22', '2005-09-23', '2005-09-24',
#                '2005-09-25', '2005-09-26', '2005-09-27', '2005-09-28',
#                '2005-09-29', '2005-09-30'],
#               dtype='datetime64[ns]', length=2983, freq=None)

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])
    # time = ds_combined.time.values
    # n_particles = len(ds_combined.EnsembleMember)

# %% [markdown]
# ## Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
# ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mea as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"NSe mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

min, max = '1997-08-01', '1998-10-01'
ax.set_xlim((pd.Timestamp(min),pd.Timestamp(max)))
ax.set_ylim((0,20))

ax.set_title(f"Run ensemble of {n_particles} particles: between {min} & {max}");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
param_names_0 = param_names[:4]
param_names_1 = param_names[4:]

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_0):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
# ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");


for i, parameter in enumerate(param_names_1):
    for j in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(parameter)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
# [ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)
