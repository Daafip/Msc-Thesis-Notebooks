# %% [markdown]
# ### Import modules and verify they work?

# %%
# general python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import numpy as np
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy
import xarray as xr
from tqdm import tqdm
import glob
from devtools import pprint

# %%
# general eWC
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models

# %%
# from ewatercycle.forcing import HBVforcing

# %% [markdown]
# Download plugin model

# %%
# pip install ewatercycle-HBV==1.3.8

# %%
# pip uninstall ewatercycle-HBV -y

# %%
# pip install --upgrade git+https://github.com/Daafip/ewatercycle-hbv.git@dev

# %% [markdown]
# #### set up paths

# %%
path = Path.cwd()
forcing_path = path / "Forcing"
observations_path = path / "Observations"
figure_path = path / "Figures"
output_path = path / "Output"
forcing_path
# Out:
# PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing')

# %% [markdown]
# #### add parameter info

# %%
## Array of initial storage terms - we keep these constant for now 
##              Si,  Su, Sf, Ss
s_0 = np.array([0,  100,  0,  5])

## Array of parameters min/max bounds as a reference
##                      Imax,  Ce,  Sumax, beta,  Pmax,  T_lag,   Kf,   Ks
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     10,    .1,   .01])
p_names = ["$I_{max}$",  "$C_e$",  "$Su_{max}$", "β",  "$P_{max}$",  "$T_{lag}$",   "$K_f$",   "$K_s$"]
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
param_names = ["Imax","Ce",  "Sumax", "Beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
stor_names = ["Si", "Su", "Sf", "Ss"]

# set initial as mean of max,min
par_0 = (p_min_initial + p_max_initial)/2

# %%
experiment_start_date = "1997-10-01T00:00:00Z"
experiment_end_date = "1998-11-01T00:00:00Z"
HRU_id = 1620500
alpha = 1.26

# %%
from ewatercycle_HBV.forcing import HBVForcing

# %%
# camels_forcing = HBVForcing(start_time = experiment_start_date,
#                           end_time = experiment_end_date,
#                           directory = forcing_path,
#                           camels_file = f'0{HRU_id}_lump_cida_forcing_leap.txt',
#                           alpha = alpha
#                           )

# %%
camels_forcing = HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'test_forcing.txt',
                          test_data_bool = True 
                          )

# %% [markdown]
# #### import model

# %%
from ewatercycle.models import HBV

# %% [markdown]
# #### import DA function:

# %%
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
DA = module_from_file("DA",r'../eWaterCycle-DA/src/eWaterCycle_DA/DA.py')

# %%
n_particles = 30

# %%
ensemble = DA.Ensemble(N=n_particles)
ensemble.setup()

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#         EnsembleMember(
#             model_name=None,
#             forcing=None,
#             setup_kwargs=None,
#             state_vector_variables='all',
#             model=None,
#             config=None,
#             state_vector=None,
#             variable_names=None,
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     observations=None,
#     logger=[],
# )

# %%
array_random_num = np.array([[np.random.random() for i in range(len(p_max_initial))] for i in range(n_particles)])
p_intial = p_min_initial + array_random_num * (p_max_initial-p_min_initial)

# %%
# values wihch you 
setup_kwargs_lst = []
for index in range(n_particles):
    setup_kwargs_lst.append({'parameters':','.join([str(p) for p in p_intial[index]]), 
                            'initial_storage':','.join([str(s) for s in s_0]),
                             })

# %%
ensemble.initialize(model_name=["HBV"]*n_particles,
                    forcing=[camels_forcing]*n_particles,
                    setup_kwargs=setup_kwargs_lst,
                    state_vector_variables=['all']*n_particles)

# %%
pprint(ensemble)
# Out:
# Ensemble(
#     N=30,
#     location='local',
#     ensemble_list=[
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.8426105310910854,0.7749647488774489,91.19324443451724,1.9891424939132891,0.17561042466117238,2.'
#                     '6815081288340865,0.049551537874356025,0.006644981430222401'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111504/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.374108999529197,0.6614179904247912,551.5415180422353,1.79852708169726,0.07529536643851632,1.981'
#                     '4699753988538,0.04499430761362817,0.005353770199849104'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111506/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.292329783651663,0.35474956584928785,81.97764578632083,2.8050097786623263,0.21861171612892485,5.'
#                     '0486352665689616,0.09671068476341114,0.0008123743408129156'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111507/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.217221880026256,0.7795081997490081,437.82242569429127,3.4290487478328457,0.08140261105372779,6.'
#                     '442173020616172,0.04280254954778989,0.006907769994593626'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111509/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.530123007615578,0.6693188771502836,174.51540516992873,3.273836164140063,0.0687099664342449,7.46'
#                     '1246483474273,0.07285237060302488,0.00022163034519678392'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111510/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.8707761053964695,0.42722857852292767,759.9473116816829,1.7734446285013046,0.049473397483223144,'
#                     '3.112065226696959,0.032130918429199996,0.00047797962489626056'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111512/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.702605113128645,0.7733639798342689,275.74983726654796,2.3355861000014304,0.28099167204050957,7.'
#                     '6306871810496775,0.0419364851682578,0.009321183604011391'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111513/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     
nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '1.2449530458458131,0.25032871793429357,128.94159276302983,1.6395277772686816,0.14783346820750443,'
#                     '9.719668738678322,0.09148369170745682,0.004532350710491528'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111544/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.209140856421962,0.2671368821328674,772.6685035147669,1.0859833995944632,0.0725248971368124,7.32'
#                     '6427876083226,0.018571947198211473,0.005491311261673881'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111546/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.339184884990792,0.22342243066485334,676.3369903185876,0.9161165646245197,0.1369937311472028,7.9'
#                     '431329415134275,0.05231068580501126,0.00845834686668376'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111547/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='test_forcing.txt',
#                 pr='HBV_forcing_2024-03-13 12_15.nc',
#                 pev='HBV_forcing_2024-03-13 12_15.nc',
#                 alpha=1.26,
#                 test_data_bool=True,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.280563479818519,0.43865279920199973,220.92772857615225,0.9588958956803486,0.047399643031855995,'
#                     '1.9410553026792048,0.09901425112630954,0.008490560450876436'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='test_forcing.txt',
#                     pr='HBV_forcing_2024-03-13 12_15.nc',
#                     pev='HBV_forcing_2024-03-13 12_15.nc',
#                     alpha=1.26,
#                     test_data_bool=True,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240313_111549/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#     ],
#     ensemble_method=None,
#     ensemble_method_name=None,
#     observed_variable_name=None,
#     observations=None,
#     logger=[],
# )

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
# testing data 
ds_obs_dir = forcing_path / ref_model.forcing.pr
ds_obs = xr.load_dataset(ds_obs_dir)

# %%
# observations = observations_path / f'0{HRU_id}_streamflow_qc.txt'

# %%
# cubic_ft_to_cubic_m = 0.0283168466

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %%
# new_header = ['GAGEID','Year','Month', 'Day', 'Streamflow(cubic feet per second)','QC_flag']
# new_header_dict = dict(list(zip(range(len(new_header)),new_header)))

# df_Q = pd.read_fwf(observations,delimiter=' ',encoding='utf-8',header=None)
# df_Q = df_Q.rename(columns=new_header_dict)
# df_Q['Streamflow(cubic feet per second)'] = df_Q['Streamflow(cubic feet per second)'].apply(lambda x: np.nan if x==-999.00 else x)
# df_Q['Q (m3/s)'] = df_Q['Streamflow(cubic feet per second)'] * cubic_ft_to_cubic_m
# df_Q['Q'] = df_Q['Q (m3/s)'] / ds.attrs['area basin(m^2)'] * 3600 * 24 * 1000 # m3/s -> m/s ->m/d -> mm/d
# df_Q.index = df_Q.apply(lambda x: pd.Timestamp(f'{int(x.Year)}-{int(x.Month)}-{int(x.Day)}'),axis=1)
# df_Q.index.name = "time"
# df_Q.drop(columns=['Year','Month', 'Day','Streamflow(cubic feet per second)'],inplace=True)
# df_Q = df_Q.dropna(axis=0)

# ds_obs_dir = observations_path / f'0{HRU_id}_streamflow_qc.nc'
# ds_obs = xr.Dataset(data_vars=df_Q[['Q']])
# if not ds_obs_dir.exists():
#     ds_obs.to_netcdf(ds_obs_dir)

# %%
# ax = df_Q['Q'].plot()
# ax.set_xlim((pd.Timestamp(experiment_start_date),pd.Timestamp(experiment_end_date)))
# ax.set_ylabel("Q (mm/d)")
# ax.set_title("observations");

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
ensemble.initialize_method(ensemble_method_name = "EnKF", 
                           observation_path = ds_obs_dir,
                           observed_variable_name = "Q",
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.005,
                                               }
                            )

# %% [markdown]
# ## Run

# %%
n_timesteps = int((ref_model.end_time - ref_model.start_time) /  ref_model.time_step)
pbar = tqdm(total=n_timesteps)

time = []
lst_state_vector = []
lst_Q = [] 
while ref_model.time < ref_model.end_time:
    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update()
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q"))
    
    pbar.update(1)
    # TODO: adjust so that tLag ? currently still often 3

# end model - IMPORTANT! when working with dockers
ensemble.finalize()
# Out:
# 23min,6sec

# %%
Q_m_arr = np.array(lst_Q).T
state_vector_arr = np.array(lst_state_vector)

# %% [markdown]
# ## TODO: improve data handeling
# ### process the numpy data into easily acessed data types

# %%
save, load = False, False
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(glob.glob(str(output_path/'df_ensemble_*.feather'))[-1]) # read last

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q": "mm/d"}

# %%
if not load:    
    data_vars = {}
    for i, name in enumerate(param_names + stor_names):
        storage_terms_i = xr.DataArray(state_vector_arr[:,:,i].T,
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled values",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])

# %% [markdown]
# # Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mean of 50 particles as a reference

# %%
def calc_NSE(Qo, Qm):
    QoAv  = np.mean(Qo)
    ErrUp = np.sum((Qm - Qo)**2)
    ErrDo = np.sum((Qo - QoAv)**2)
    return 1 - (ErrUp / ErrDo)

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(ds_obs['Q'].sel(time=time).values,mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
ds_obs['Q'].sel(time=time).plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
ax_pr.bar(df_ensemble.index,ds['pr'].values[:len(time)],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        ds_combined[stor_names[i]].isel(EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, ax = plt.subplots(1,1)

parameter="Tlag"
for i in range(n_particles):
    ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax)
ax.set_title(f'parameter={parameter} for {n_particles} Ensemble Members');

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        ds_combined[parameter].isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)
